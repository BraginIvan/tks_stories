# %%
import pandas as pd
import numpy as np
from catboost import CatBoostClassifier, Pool,CatBoost, CatBoostRegressor
from collections import Counter
from keras.layers import Dense, Dropout, Embedding, Input, Reshape, Concatenate, Input, Flatten, LeakyReLU,BatchNormalization
from keras.models import Model
from keras import optimizers
from keras import regularizers
import json
import re
# Out:
# Using TensorFlow backend.
# /home/ivan/projects/tks_stories/venv/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/ivan/projects/tks_stories/venv/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/ivan/projects/tks_stories/venv/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/ivan/projects/tks_stories/venv/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/ivan/projects/tks_stories/venv/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/ivan/projects/tks_stories/venv/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /home/ivan/projects/tks_stories/venv/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/ivan/projects/tks_stories/venv/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/ivan/projects/tks_stories/venv/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/ivan/projects/tks_stories/venv/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/ivan/projects/tks_stories/venv/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/ivan/projects/tks_stories/venv/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
def jsons_name_type(jsons_name):
    if not jsons_name:
        return -1
    if "Цифра дня" in jsons_name:
        return 1
    if "AliExpress" in jsons_name:
        return 2 
    if "Тинькофф" in jsons_name or "Tinkoff" in jsons_name:
        return 3
    if "ЧМ" in jsons_name:
        return 4
    if "фильм"  in jsons_name or "смотрет"  in jsons_name:
        return 5
    if "кредит"  in jsons_name:
        return 6
    if "инвестиц"  in jsons_name:
        return 7
    if "₽"  in jsons_name or "$"  in jsons_name:
        return 8
    if "тпуск"  in jsons_name:
        return 9
    return 0

# %%
data_path = 'dataset/'
customer_train = pd.read_csv(f'{data_path}customer_train.csv')
customer_train['first_session_dttm']=pd.to_datetime(customer_train['first_session_dttm'],infer_datetime_format=True)
customer_test = pd.read_csv(f'{data_path}customer_test.csv')
customer_test['first_session_dttm']=pd.to_datetime(customer_test['first_session_dttm'],infer_datetime_format=True)
stories_description = pd.read_csv(f'{data_path}stories_description.csv')

stories_reaction_test = pd.read_csv(f'{data_path}stories_reaction_test.csv')
stories_reaction_test['event_dttm']=pd.to_datetime(stories_reaction_test['event_dttm'],infer_datetime_format=True)
stories_reaction_train = pd.read_csv(f'{data_path}stories_reaction_train.csv')
stories_reaction_train['event_dttm']=pd.to_datetime(stories_reaction_train['event_dttm'],infer_datetime_format=True)
transactions = pd.read_csv(f'{data_path}transactions.csv')


sample_submit = pd.read_csv(f'{data_path}sample_submit.csv')

# %%
subsets = stories_reaction_train.groupby(['customer_id', 'event_dttm']).count().reset_index()[['customer_id', 'event_dttm', 'story_id']]
subsets.columns = ['customer_id', 'event_dttm','subsets']
stories_reaction_train=stories_reaction_train.merge(subsets, on=['customer_id', 'event_dttm'], how='left')

subsets = stories_reaction_test.groupby(['customer_id', 'event_dttm']).count().reset_index()[['customer_id', 'event_dttm', 'story_id']]
subsets.columns = ['customer_id', 'event_dttm','subsets']
stories_reaction_test=stories_reaction_test.merge(subsets, on=['customer_id', 'event_dttm'], how='left')

# %%
stories_reaction_train['reaction_hour']=stories_reaction_train.event_dttm.dt.hour
stories_reaction_test['reaction_hour']=stories_reaction_test.event_dttm.dt.hour
stories_reaction_train['reaction_dayofweek']=stories_reaction_train.event_dttm.dt.dayofweek
stories_reaction_test['reaction_dayofweek']=stories_reaction_test.event_dttm.dt.dayofweek

stories_description['jsons'] = stories_description.story_json.map(lambda x:json.loads(x.replace("\\\\", "\\")))
stories_description['jsons_name'] =stories_description.jsons.map(lambda x:x['properties'].get('name'))
stories_description['texts'] =stories_description.jsons.map(lambda x:re.findall(""""text": \"([^\"]*)\",""", json.dumps(x, ensure_ascii=False)))
stories_description['jsons_name_type'] = stories_description.jsons_name.map(lambda x:jsons_name_type(x))

# %%
customer_train['first_session_dttm_year']=(customer_train.first_session_dttm.dt.year-2000)/20

# %%
train_and_val = stories_reaction_train.merge(customer_train, on='customer_id', how='left')
train_and_val = train_and_val.merge(stories_description, on='story_id', how='left')

test = stories_reaction_test.merge(customer_test, on='customer_id', how='left')
test = test.merge(stories_description, on='story_id', how='left')

train_and_val=train_and_val.fillna(0)
# train_and_val.fillnull(0)

# %%
train_dates = stories_reaction_train['event_dttm'].astype(np.int64)
test_dates = stories_reaction_test['event_dttm'].astype(np.int64)
period = train_dates.max() - (test_dates.max() - test_dates.min())

# np.random.seed(19)
# msk = np.random.rand(len(train_and_val)) < 0.8
# train = train_and_val[msk]
# val = train_and_val[~msk]

val = train_and_val[train_and_val.event_dttm.astype(np.int64) > period]
train = train_and_val[train_and_val.event_dttm.astype(np.int64) <= period]

# %%
# customer_shows = train.groupby('customer_id')['event'].count().to_frame().reset_index() 
# customer_shows.columns = ['customer_id', 'customer_shows']
# customer_shows=customer_shows.fillna(0)
# train=train.merge(customer_shows, on='customer_id')
# val=val.merge(customer_shows, on='customer_id', how='left')
# train['customer_shows']=train.customer_shows.fillna(-999)
# val['customer_shows']=val.customer_shows.fillna(-999)

# %%
len(train), len(val)
# Out:
# (320248, 152893)

# %%
train['gender_cd']=train.gender_cd.map(lambda x: 1 if x =="M" else(0 if x =="F" else -1))
val['gender_cd']=val.gender_cd.map(lambda x: 1 if x =="M" else(0 if x =="F" else -1))
val['children_cnt']=val.children_cnt/10
train['children_cnt']=train.children_cnt/10
# Out:
# /home/ivan/projects/tks_stories/venv/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /home/ivan/projects/tks_stories/venv/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/ivan/projects/tks_stories/venv/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /home/ivan/projects/tks_stories/venv/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
def to_OHE(field):
    count = len(set(train_and_val[field].values))
    d = dict(zip(list(set(train_and_val[field].values)), range(count)))
    train[field]=train[field].map(lambda x:  d[x])
    val[field]=val[field].map(lambda x:  d[x])
    return count
customers_count = to_OHE('customer_id')
# marital_status_count = to_OHE('marital_status_cd')
stories_count = to_OHE('story_id')
# job_position_count = to_OHE('job_position_cd')
# job_title_count = to_OHE('job_title')
jsons_name_type_count = to_OHE('jsons_name_type')
# Out:
# /home/ivan/projects/tks_stories/venv/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /home/ivan/projects/tks_stories/venv/lib/python3.6/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """

# %%
values = set(train_and_val[['product_0', 'product_1', 'product_2', 'product_3', 'product_4', 'product_5', 'product_6']].values.reshape(-1))
producs_count = len(values)
d = dict(zip(list(values), range(1, len(values)+1)))
for f in ['product_0', 'product_1', 'product_2', 'product_3', 'product_4', 'product_5', 'product_6']:
    train[f]=train[f].map(lambda x:  d[x])
    val[f]=val[f].map(lambda x:  d[x])
# Out:
# /home/ivan/projects/tks_stories/venv/lib/python3.6/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# /home/ivan/projects/tks_stories/venv/lib/python3.6/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
import keras.backend as K
def metric_loss(batch_size):
    d = np.sum(np.abs(valY))
    def the_loss(y_true, y_pred):
        return -(len(val.customer_id.values)/batch_size)*K.sum(y_true*y_pred)/d
    return(the_loss)

# %%
def reaction_to_class(reaction):
    if reaction=="dislike":
        return -10
    if reaction=="like":
        return 0.5
    if reaction=="view":
        return 0.1
    if reaction=="skip":
        return -0.1
trainY = np.array(list(train.event.map(lambda x: reaction_to_class(x)).values))
valY = np.array(list(val.event.map(lambda x: reaction_to_class(x)).values))

# %%
model_input_customer = Input((1,), name='customer_id')
customer = Embedding(customers_count+1, 4, input_length=1)(model_input_customer)
customer = Flatten()(customer)

model_input_story = Input((1,), name='story_id')
story = Embedding(stories_count, 2, input_length=1)(model_input_story)
story = Flatten()(story)

model_input_products = Input((7,), name='producs')
products = Embedding(producs_count, 2, input_length=7)(model_input_products)
products = Flatten()(products)



model_input_story_name = Input((1,), name='story_name_id')
story_name = Embedding(jsons_name_type_count, 2, input_length=1)(model_input_story_name)
story_name = Flatten()(story_name)

model_input_subset = Input((1,), name='model_input_subset')



model_input_3 = Input((3,), name='customer_data')
model_input_4 = Input((2,), name='customer_data2')

x_numeric = Concatenate()([model_input_3, model_input_4, model_input_subset])
x_numeric = Dense(8, 
          activation='relu', 
         )(x_numeric)
x_cat = Concatenate()([customer, story, products, story_name])

x = Concatenate()([customer, story])


x = Dense(8, 
          activation='relu', 
         )(x)







x = Dense(1, activation='tanh')(x)
model = Model([model_input_customer, 
               model_input_story, 
               model_input_story_name,
               model_input_subset,
               model_input_3,
               model_input_4, 
               model_input_products,
              ], x)





print(model.summary())
# Out:
# Model: "model_27"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# customer_id (InputLayer)        (None, 1)            0
# __________________________________________________________________________________________________
# story_id (InputLayer)           (None, 1)            0
# __________________________________________________________________________________________________
# embedding_50 (Embedding)        (None, 1, 4)         164008      customer_id[0][0]
# __________________________________________________________________________________________________
# embedding_51 (Embedding)        (None, 1, 2)         1826        story_id[0][0]
# __________________________________________________________________________________________________
# flatten_50 (Flatten)            (None, 4)            0           embedding_50[0][0]
# __________________________________________________________________________________________________
# flatten_51 (Flatten)            (None, 2)            0           embedding_51[0][0]
# __________________________________________________________________________________________________
# concatenate_43 (Concatenate)    (None, 6)            0           flatten_50[0][0]
#                                                                  flatten_51[0][0]
# __________________________________________________________________________________________________
# dense_80 (Dense)                (None, 8)            56          concatenate_43[0][0]
# __________________________________________________________________________________________________
# dense_81 (Dense)                (None, 1)            9           dense_80[0][0]
# ==================================================================================================
# Total params: 165,899
# Trainable params: 165,899
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %%
# batch_size=320248
batch_size=64
adam = optimizers.Adamax(lr=0.03)
model.compile(optimizer=adam, loss=metric_loss(batch_size))

# %%
model.fit(
    shuffle=True,
        x = [train.customer_id.values,
             train.story_id.values,
             train.jsons_name_type.values, 
             train.subsets.values/20,
             
             train[['gender_cd', 'children_cnt', 'first_session_dttm_year']].values,
             train[['reaction_hour', 'reaction_dayofweek']].values/30,
             train[['product_0', 'product_1', 'product_2', 'product_3', 'product_4', 'product_5', 'product_6']].values,
            ], 
          y = trainY,
          batch_size=batch_size,
          epochs=5,
          validation_data=([val.customer_id.values, 
                            val.story_id.values, 
                            val.jsons_name_type.values, 
                            val.subsets.values/20,
                            val[['gender_cd', 'children_cnt', 'first_session_dttm_year']].values,
                            val[['reaction_hour', 'reaction_dayofweek']].values/30,
                            val[['product_0', 'product_1', 'product_2', 'product_3', 'product_4', 'product_5', 'product_6']].values,
                           ], valY),
         )

# 320248/320248 [==============================] - 13s 41us/step - loss: -0.6153 - val_loss: -0.3492
# 320248/320248 [==============================] - 13s 42us/step - loss: -0.7373 - val_loss: -0.3607
# 320248/320248 [==============================] - 14s 42us/step - loss: -0.7263 - val_loss: -0.3656 size 4 tanh
# 320248/320248 [==============================] - 14s 43us/step - loss: -0.7046 - val_loss: -0.3612 size 128 relu
# 320248/320248 [==============================] - 14s 44us/step - loss: -0.7110 - val_loss: -0.3455 size 128 lrelu
# 320248/320248 [==============================] - 14s 43us/step - loss: -0.6390 - val_loss: -0.3683 size 128 relu increase embs
# 320248/320248 [==============================] - 16s 48us/step - loss: -0.6319 - val_loss: -0.3705 job_position_cd


# 378578/378578 [==============================] - 61s 161us/step - loss: -0.4684 - val_loss: -0.4269
# 378578/378578 [==============================] - 15s 41us/step - loss: -0.5597 - val_loss: -0.4413
# 378578/378578 [==============================] - 2s 6us/step - loss: -0.5903 - val_loss: -0.4453
# Out:
# Train on 320248 samples, validate on 152893 samples
# Epoch 1/5
# 320248/320248 [==============================] - 14s 42us/step - loss: -0.4675 - val_loss: -0.3164
# Epoch 2/5
# 290816/320248 [==========================>...] - ETA: 1s - loss: -0.5350

# %%
# train_predict = model.predict([train.customer_id.values,
#              train.story_id.values,
#              0*train.jsons_name_type.values, 
#              train.job_title.values,
#              train.job_position_cd.values,
#              0*train.marital_status_cd.values,
#              train[['age', 'gender_cd', 'children_cnt', 'first_session_dttm_year']].values,
#              train[[ 'customer_shows']].values/3000,
#              0*train[['transaction_amt_count', 'transaction_amt_min', 'transaction_amt_max']].values,
#              train[['reaction_hour', 'reaction_dayofweek']].values/30,
#              train[['product_0', 'product_1', 'product_2', 'product_3', 'product_4', 'product_5', 'product_6']].values
#            ])
val_predict = model.predict([val.customer_id.values, 
                            val.story_id.values, 
                            val.jsons_name_type.values, 
                            val.subsets.values/20,
                            val[['gender_cd', 'children_cnt', 'first_session_dttm_year']].values,
                            val[['reaction_hour', 'reaction_dayofweek']].values/30,
                            val[['product_0', 'product_1', 'product_2', 'product_3', 'product_4', 'product_5', 'product_6']].values,
                            ])
# train_predict = model.predict(train.customer_id.values)
# val_predict = model.predict(val.customer_id.values)
-np.sum(valY*val_predict[:,0] )/np.sum(np.abs(valY))
# -0.3585501646600242
# -0.35612893805432966
# Out:
# -0.26003999234284453

# %%
customer_embs = {i:data  for i, data in enumerate(model.layers[2].get_weights()[0])}

# %%
print(customer_embs[0],
    customer_embs[3],
customer_embs[1],
customer_embs[10],
customer_embs[59])
# Out:
# [ 0.005168   -0.01438476  0.00292583 -0.0085938 ] [ 0.01547688 -0.01577654  0.01930975 -0.01993946] [-0.02189168  0.00589681 -0.01562697 -0.05019472] [-0.01738    -0.00801099  0.01565425  0.03672253] [ 0.01562387 -0.01673105  0.00908378 -0.01530081]

# %%
print(
   customer_embs[0], 
    customer_embs[3],
customer_embs[1],
customer_embs[10],
customer_embs[59])
# Out:
# [ 0.005168   -0.01438476  0.00292583 -0.0085938 ] [ 0.01547688 -0.01577654  0.01930975 -0.01993946] [-0.02189168  0.00589681 -0.01562697 -0.05019472] [-0.01738    -0.00801099  0.01565425  0.03672253] [ 0.01562387 -0.01673105  0.00908378 -0.01530081]

# %%
customer_embs[1]
# Out:
# array([-0.02189168,  0.00589681, -0.01562697, -0.05019472], dtype=float32)

# %%
customer_embs[10]
# Out:
# array([-0.01738   , -0.00801099,  0.01565425,  0.03672253], dtype=float32)

# %%
customer_embs[59]
# Out:
# array([ 0.01562387, -0.01673105,  0.00908378, -0.01530081], dtype=float32)

# %%
train_customer_ids = set(train.customer_id.values)
val_customer_ids = set(val.customer_id.values) - train_customer_ids
print(len(train_customer_ids), len(val_customer_ids))
# Out:
# 32267 8734

# %%
val_customer_ids.intersection(train_customer_ids)
# Out:
# set()

# %%
train_customer = train.copy().drop_duplicates(subset=['customer_id'])
val_customer = val[val.customer_id.isin(val_customer_ids)].drop_duplicates(subset=['customer_id'])

# %%
train_customerY = train_customer.customer_id.map(lambda x : customer_embs[x])
val_customerY = val_customer.customer_id.map(lambda x : customer_embs[x])

# %%
model_input_products = Input((7,), name='producs')
products = Embedding(producs_count, 1, input_length=7)(model_input_products)
products = Flatten()(products)


model_input_3 = Input((3,), name='customer_data')
model_input_4 = Input((2,), name='customer_data2')

x = Concatenate()([ products, model_input_3, model_input_4])


x = Dense(16, 
          activation='tanh', 
         )(x)


x = Dense(8, 
          activation='tanh', 
         )(x)



x = Dense(4, activation='tanh')(x)
model2 = Model([
               model_input_3,
               model_input_4, 
               model_input_products,
              ], x)




model2.summary()
# Out:
# Model: "model_30"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# producs (InputLayer)            (None, 7)            0
# __________________________________________________________________________________________________
# embedding_56 (Embedding)        (None, 7, 1)         4           producs[0][0]
# __________________________________________________________________________________________________
# flatten_56 (Flatten)            (None, 7)            0           embedding_56[0][0]
# __________________________________________________________________________________________________
# customer_data (InputLayer)      (None, 3)            0
# __________________________________________________________________________________________________
# customer_data2 (InputLayer)     (None, 2)            0
# __________________________________________________________________________________________________
# concatenate_46 (Concatenate)    (None, 12)           0           flatten_56[0][0]
#                                                                  customer_data[0][0]
#                                                                  customer_data2[0][0]
# __________________________________________________________________________________________________
# dense_88 (Dense)                (None, 16)           208         concatenate_46[0][0]
# __________________________________________________________________________________________________
# dense_89 (Dense)                (None, 8)            136         dense_88[0][0]
# __________________________________________________________________________________________________
# dense_90 (Dense)                (None, 4)            36          dense_89[0][0]
# ==================================================================================================
# Total params: 384
# Trainable params: 384
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
train_customer1 = train_customer[train_customer.customer_id < 10000]
train_customer2 = train_customer[train_customer.customer_id >= 10000]

train_customerY1 = train_customer1.customer_id.map(lambda x : customer_embs[x])
train_customerY2 = train_customer2.customer_id.map(lambda x : customer_embs[x])

# %%
# batch_size=320248
batch_size=640
adam = optimizers.Adamax(lr=0.001)
model2.compile(optimizer=adam, loss='mse')

# %%
model2.fit(
        x = [
             train_customer1[['gender_cd', 'children_cnt', 'first_session_dttm_year']].values,
             train_customer1[['reaction_hour', 'reaction_dayofweek']].values/30,
             train_customer1[['product_0', 'product_1', 'product_2', 'product_3', 'product_4', 'product_5', 'product_6']].values,
            ], 
          y = np.stack(train_customerY1.values),
          batch_size=batch_size,
          epochs=100,
          validation_data=([
              train_customer2[['gender_cd', 'children_cnt', 'first_session_dttm_year']].values,
              train_customer2[['reaction_hour', 'reaction_dayofweek']].values/30,
              train_customer2[['product_0', 'product_1', 'product_2', 'product_3', 'product_4', 'product_5', 'product_6']].values,
          ], np.stack(train_customerY2.values)),
    )
# Out:
# Train on 7866 samples, validate on 24401 samples
# Epoch 1/100
# 7866/7866 [==============================] - 1s 97us/step - loss: 0.0618 - val_loss: 0.0311
# Epoch 2/100
# 7866/7866 [==============================] - 0s 11us/step - loss: 0.0212 - val_loss: 0.0138
# Epoch 3/100
# 7866/7866 [==============================] - 0s 12us/step - loss: 0.0114 - val_loss: 0.0094
# Epoch 4/100
# 7866/7866 [==============================] - 0s 12us/step - loss: 0.0081 - val_loss: 0.0072
# Epoch 5/100
# 7866/7866 [==============================] - 0s 13us/step - loss: 0.0066 - val_loss: 0.0065
# Epoch 6/100
# 7866/7866 [==============================] - 0s 18us/step - loss: 0.0062 - val_loss: 0.0063
# Epoch 7/100
# 7866/7866 [==============================] - 0s 19us/step - loss: 0.0060 - val_loss: 0.0061
# Epoch 8/100
# 7866/7866 [==============================] - 0s 13us/step - loss: 0.0059 - val_loss: 0.0059
# Epoch 9/100
# 7866/7866 [==============================] - 0s 13us/step - loss: 0.0058 - val_loss: 0.0058
# Epoch 10/100
# 7866/7866 [==============================] - 0s 13us/step - loss: 0.0057 - val_loss: 0.0057
# Epoch 11/100
# 7866/7866 [==============================] - 0s 13us/step - loss: 0.0056 - val_loss: 0.0056
# Epoch 12/100
# 7866/7866 [==============================] - 0s 13us/step - loss: 0.0055 - val_loss: 0.0055
# Epoch 13/100
# 7866/7866 [==============================] - 0s 16us/step - loss: 0.0054 - val_loss: 0.0054
# Epoch 14/100
# 7866/7866 [==============================] - 0s 17us/step - loss: 0.0053 - val_loss: 0.0054
# Epoch 15/100
# 7866/7866 [==============================] - 0s 13us/step - loss: 0.0052 - val_loss: 0.0053
# Epoch 16/100
# 7866/7866 [==============================] - 0s 12us/step - loss: 0.0052 - val_loss: 0.0052
# Epoch 17/100
# 7866/7866 [==============================] - 0s 12us/step - loss: 0.0051 - val_loss: 0.0052
# Epoch 18/100
# 7866/7866 [==============================] - 0s 12us/step - loss: 0.0051 - val_loss: 0.0051
# Epoch 19/100
# 7866/7866 [==============================] - 0s 12us/step - loss: 0.0050 - val_loss: 0.0050
# Epoch 20/100
# 7866/7866 [==============================] - 0s 17us/step - loss: 0.0050 - val_loss: 0.0050
# Epoch 21/100
# 7866/7866 [==============================] - 0s 17us/step - loss: 0.0049 - val_loss: 0.0049
# Epoch 22/100
# 7866/7866 [==============================] - 0s 13us/step - loss: 0.0049 - val_loss: 0.0049
# Epoch 23/100
# 7866/7866 [==============================] - 0s 13us/step - loss: 0.0048 - val_loss: 0.0049
# Epoch 24/100
# 7866/7866 [==============================] - 0s 13us/step - loss: 0.0048 - val_loss: 0.0048
# Epoch 25/100
# 7866/7866 [==============================] - 0s 13us/step - loss: 0.0048 - val_loss: 0.0048
# Epoch 26/100
# 7866/7866 [==============================] - 0s 13us/step - loss: 0.0047 - val_loss: 0.0047
# Epoch 27/100
# 7866/7866 [==============================] - 0s 13us/step - loss: 0.0047 - val_loss: 0.0047
# Epoch 28/100
# 7866/7866 [==============================] - 0s 13us/step - loss: 0.0047 - val_loss: 0.0047
# Epoch 29/100
# 7866/7866 [==============================] - 0s 13us/step - loss: 0.0046 - val_loss: 0.0046
# Epoch 30/100
# 7866/7866 [==============================] - 0s 13us/step - loss: 0.0046 - val_loss: 0.0046
# Epoch 31/100
# 7866/7866 [==============================] - 0s 12us/step - loss: 0.0046 - val_loss: 0.0046
# Epoch 32/100
# 7866/7866 [==============================] - 0s 12us/step - loss: 0.0045 - val_loss: 0.0046
# Epoch 33/100
# 7866/7866 [==============================] - 0s 13us/step - loss: 0.0045 - val_loss: 0.0045
# Epoch 34/100
# 7866/7866 [==============================] - 0s 13us/step - loss: 0.0045 - val_loss: 0.0045
# Epoch 35/100
# 7866/7866 [==============================] - 0s 13us/step - loss: 0.0045 - val_loss: 0.0045
# Epoch 36/100
# 7866/7866 [==============================] - 0s 13us/step - loss: 0.0044 - val_loss: 0.0045
# Epoch 37/100
# 7866/7866 [==============================] - 0s 12us/step - loss: 0.0044 - val_loss: 0.0044
# Epoch 38/100
# 7866/7866 [==============================] - 0s 11us/step - loss: 0.0044 - val_loss: 0.0044
# Epoch 39/100
# 7866/7866 [==============================] - 0s 13us/step - loss: 0.0044 - val_loss: 0.0044
# Epoch 40/100
# 7866/7866 [==============================] - 0s 11us/step - loss: 0.0044 - val_loss: 0.0044
# Epoch 41/100
# 7866/7866 [==============================] - 0s 12us/step - loss: 0.0043 - val_loss: 0.0044
# Epoch 42/100
# 7866/7866 [==============================] - 0s 12us/step - loss: 0.0043 - val_loss: 0.0043
# Epoch 43/100
# 7866/7866 [==============================] - 0s 11us/step - loss: 0.0043 - val_loss: 0.0043
# Epoch 44/100
# 7866/7866 [==============================] - 0s 12us/step - loss: 0.0043 - val_loss: 0.0043
# Epoch 45/100
# 7866/7866 [==============================] - 0s 12us/step - loss: 0.0043 - val_loss: 0.0043
# Epoch 46/100
# 7866/7866 [==============================] - 0s 12us/step - loss: 0.0043 - val_loss: 0.0043
# Epoch 47/100
# 7866/7866 [==============================] - 0s 14us/step - loss: 0.0042 - val_loss: 0.0043
# Epoch 48/100
# 7866/7866 [==============================] - 0s 14us/step - loss: 0.0042 - val_loss: 0.0043
# Epoch 49/100
# 7866/7866 [==============================] - 0s 13us/step - loss: 0.0042 - val_loss: 0.0042
# Epoch 50/100
# 7866/7866 [==============================] - 0s 15us/step - loss: 0.0042 - val_loss: 0.0042
# Epoch 51/100
# 7866/7866 [==============================] - 0s 17us/step - loss: 0.0042 - val_loss: 0.0042
# Epoch 52/100
# 7866/7866 [==============================] - 0s 13us/step - loss: 0.0042 - val_loss: 0.0042
# Epoch 53/100
# 7866/7866 [==============================] - 0s 13us/step - loss: 0.0042 - val_loss: 0.0042
# Epoch 54/100
# 7866/7866 [==============================] - 0s 14us/step - loss: 0.0042 - val_loss: 0.0042
# Epoch 55/100
# 7866/7866 [==============================] - 0s 14us/step - loss: 0.0041 - val_loss: 0.0042
# Epoch 56/100
# 7866/7866 [==============================] - 0s 14us/step - loss: 0.0041 - val_loss: 0.0042
# Epoch 57/100
# 7866/7866 [==============================] - 0s 14us/step - loss: 0.0041 - val_loss: 0.0041
# Epoch 58/100
# 7866/7866 [==============================] - 0s 13us/step - loss: 0.0041 - val_loss: 0.0041
# Epoch 59/100
# 7866/7866 [==============================] - 0s 14us/step - loss: 0.0041 - val_loss: 0.0041
# Epoch 60/100
# 7866/7866 [==============================] - 0s 14us/step - loss: 0.0041 - val_loss: 0.0041
# Epoch 61/100
# 7866/7866 [==============================] - 0s 14us/step - loss: 0.0041 - val_loss: 0.0041
# Epoch 62/100
# 7866/7866 [==============================] - 0s 15us/step - loss: 0.0041 - val_loss: 0.0041
# Epoch 63/100
# 7866/7866 [==============================] - 0s 14us/step - loss: 0.0041 - val_loss: 0.0041
# Epoch 64/100
# 7866/7866 [==============================] - 0s 13us/step - loss: 0.0041 - val_loss: 0.0041
# Epoch 65/100
# 7866/7866 [==============================] - 0s 14us/step - loss: 0.0040 - val_loss: 0.0041
# Epoch 66/100
# 7866/7866 [==============================] - 0s 14us/step - loss: 0.0040 - val_loss: 0.0041
# Epoch 67/100
# 7866/7866 [==============================] - 0s 14us/step - loss: 0.0040 - val_loss: 0.0041
# Epoch 68/100
# 7866/7866 [==============================] - 0s 13us/step - loss: 0.0040 - val_loss: 0.0040
# Epoch 69/100
# 7866/7866 [==============================] - 0s 13us/step - loss: 0.0040 - val_loss: 0.0040
# Epoch 70/100
# 7866/7866 [==============================] - 0s 14us/step - loss: 0.0040 - val_loss: 0.0040
# Epoch 71/100
# 7866/7866 [==============================] - 0s 14us/step - loss: 0.0040 - val_loss: 0.0040
# Epoch 72/100
# 7866/7866 [==============================] - 0s 14us/step - loss: 0.0040 - val_loss: 0.0040
# Epoch 73/100
# 7866/7866 [==============================] - 0s 14us/step - loss: 0.0040 - val_loss: 0.0040
# Epoch 74/100
# 7866/7866 [==============================] - 0s 13us/step - loss: 0.0040 - val_loss: 0.0040
# Epoch 75/100
# 7866/7866 [==============================] - 0s 13us/step - loss: 0.0040 - val_loss: 0.0040
# Epoch 76/100
# 7866/7866 [==============================] - 0s 14us/step - loss: 0.0040 - val_loss: 0.0040
# Epoch 77/100
# 7866/7866 [==============================] - 0s 15us/step - loss: 0.0040 - val_loss: 0.0040
# Epoch 78/100
# 7866/7866 [==============================] - 0s 13us/step - loss: 0.0040 - val_loss: 0.0040
# Epoch 79/100
# 7866/7866 [==============================] - 0s 14us/step - loss: 0.0040 - val_loss: 0.0040
# Epoch 80/100
# 7866/7866 [==============================] - 0s 13us/step - loss: 0.0040 - val_loss: 0.0040
# Epoch 81/100
# 7866/7866 [==============================] - 0s 18us/step - loss: 0.0040 - val_loss: 0.0040
# Epoch 82/100
# 7866/7866 [==============================] - 0s 18us/step - loss: 0.0039 - val_loss: 0.0040
# Epoch 83/100
# 7866/7866 [==============================] - 0s 17us/step - loss: 0.0039 - val_loss: 0.0040
# Epoch 84/100
# 7866/7866 [==============================] - 0s 15us/step - loss: 0.0039 - val_loss: 0.0040
# Epoch 85/100
# 7866/7866 [==============================] - 0s 14us/step - loss: 0.0039 - val_loss: 0.0040
# Epoch 86/100
# 7866/7866 [==============================] - 0s 15us/step - loss: 0.0039 - val_loss: 0.0040
# Epoch 87/100
# 7866/7866 [==============================] - 0s 15us/step - loss: 0.0039 - val_loss: 0.0040
# Epoch 88/100
# 7866/7866 [==============================] - 0s 15us/step - loss: 0.0039 - val_loss: 0.0039
# Epoch 89/100
# 7866/7866 [==============================] - 0s 16us/step - loss: 0.0039 - val_loss: 0.0039
# Epoch 90/100
# 7866/7866 [==============================] - 0s 14us/step - loss: 0.0039 - val_loss: 0.0039
# Epoch 91/100
# 7866/7866 [==============================] - 0s 15us/step - loss: 0.0039 - val_loss: 0.0039
# Epoch 92/100
# 7866/7866 [==============================] - 0s 15us/step - loss: 0.0039 - val_loss: 0.0039
# Epoch 93/100
# 7866/7866 [==============================] - 0s 15us/step - loss: 0.0039 - val_loss: 0.0039
# Epoch 94/100
# 7866/7866 [==============================] - 0s 15us/step - loss: 0.0039 - val_loss: 0.0039
# Epoch 95/100
# 7866/7866 [==============================] - 0s 15us/step - loss: 0.0039 - val_loss: 0.0039
# Epoch 96/100
# 7866/7866 [==============================] - 0s 16us/step - loss: 0.0039 - val_loss: 0.0039
# Epoch 97/100
# 7866/7866 [==============================] - 0s 16us/step - loss: 0.0039 - val_loss: 0.0039
# Epoch 98/100
# 7866/7866 [==============================] - 0s 15us/step - loss: 0.0039 - val_loss: 0.0039
# Epoch 99/100
# 7866/7866 [==============================] - 0s 16us/step - loss: 0.0039 - val_loss: 0.0039
# Epoch 100/100
# 7866/7866 [==============================] - 0s 17us/step - loss: 0.0039 - val_loss: 0.0039

# %%
val_customer_predict = model2.predict([

    val_customer[['gender_cd', 'children_cnt', 'first_session_dttm_year']].values,
    val_customer[['reaction_hour', 'reaction_dayofweek']].values/30,
    val_customer[['product_0', 'product_1', 'product_2', 'product_3', 'product_4', 'product_5', 'product_6']].values,
])

# %%
train_customer_predict = model2.predict([

    train_customer[['gender_cd', 'children_cnt', 'first_session_dttm_year']].values,
    train_customer[['reaction_hour', 'reaction_dayofweek']].values/30,
    train_customer[['product_0', 'product_1', 'product_2', 'product_3', 'product_4', 'product_5', 'product_6']].values,
])

# %%
new_weights = {x:y for x,y in zip(val_customer.customer_id.values, val_customer_predict)}
new_weights2 = {x:y for x,y in zip(train_customer.customer_id.values, train_customer_predict)}

old_weights = model.layers[2].get_weights()[0]

# %%
old_weights[5]
# Out:
# array([ 0.0099319 , -0.01611329,  0.01323292, -0.01132959], dtype=float32)

# %%
new_weights
# Out:
# {39: array([ 0.03403804, -0.04165976,  0.03608559, -0.02104231], dtype=float32),
#  211: array([ 0.02441036,  0.00269812,  0.01525126, -0.02018406], dtype=float32),
#  263: array([ 0.00127809,  0.01049209,  0.00340006, -0.01293281], dtype=float32),
#  274: array([ 0.01545817, -0.02379564, -0.00546828, -0.00719849], dtype=float32),
#  317: array([ 0.01877853, -0.02098448,  0.0160792 , -0.02518245], dtype=float32),
#  339: array([ 0.01395899, -0.00160259, -0.00220951, -0.01982732], dtype=float32),
#  433: array([ 0.01615662, -0.01198284, -0.00338601, -0.00345146], dtype=float32),
#  617: array([ 0.00773076, -0.03633916,  0.02123952, -0.00801514], dtype=float32),
#  683: array([ 0.02239284, -0.0280975 ,  0.01323248, -0.00402309], dtype=float32),
#  715: array([ 0.03280096, -0.06365255,  0.02435496, -0.02098906], dtype=float32),
#  759: array([ 0.01542099, -0.02165662,  0.01209157, -0.00320122], dtype=float32),
#  761: array([ 0.01976085, -0.02175014,  0.0035015 , -0.01849779], dtype=float32),
#  765: array([ 0.01000244, -0.04117203,  0.01660251, -0.00536791], dtype=float32),
#  803: array([ 0.01214697, -0.00519997,  0.01230645, -0.01344477], dtype=float32),
#  818: array([ 0.03018475, -0.04523414,  0.0243047 , -0.01889081], dtype=float32),
#  830: array([ 0.02416391, -0.05188497,  0.01920972, -0.01463265], dtype=float32),
#  848: array([ 0.01483595, -0.01893313, -0.00539221, -0.00091535], dtype=float32),
#  864: array([ 0.02376031, -0.03197205,  0.00643129, -0.01115639], dtype=float32),
#  933: array([ 0.01346725, -0.00981272,  0.01149173, -0.01012154], dtype=float32),
#  975: array([ 0.01187987, -0.01054486, -0.00556134, -0.01266081], dtype=float32),
#  997: array([ 0.03200112, -0.00906916,  0.01868031, -0.01345004], dtype=float32),
#  1027: array([ 0.02552558, -0.01715436,  0.0224017 , -0.0190072 ], dtype=float32),
#  1046: array([-0.01763784,  0.00910059, -0.01747322,  0.00290436], dtype=float32),
#  1052: array([ 0.02253335, -0.02005014,  0.00848656, -0.01069911], dtype=float32),
#  1120: array([ 0.03725683, -0.04327717,  0.03463249, -0.01893651], dtype=float32),
#  1146: array([ 0.01440111, -0.00236574,  0.00220583, -0.01428054], dtype=float32),
#  1188: array([ 0.03681694, -0.03523245,  0.01211425, -0.01493548], dtype=float32),
#  1198: array([ 0.01146202, -0.00058084,  0.00301429, -0.01628822], dtype=float32),
#  1214: array([ 0.0312412 , -0.04294529,  0.01229569, -0.00910094], dtype=float32),
#  1218: array([ 0.02813704, -0.03130241,  0.01720175, -0.00392852], dtype=float32),
#  1286: array([ 0.01766681, -0.02802196,  0.01612275, -0.01878792], dtype=float32),
#  1359: array([-0.00717341,  0.00296666,  0.01031378, -0.01861155], dtype=float32),
#  1574: array([ 0.01296815, -0.00717574,  0.00903592, -0.01557329], dtype=float32),
#  1647: array([ 0.02287669, -0.03006835,  0.02736863, -0.02653597], dtype=float32),
#  1651: array([ 0.01408398, -0.03375086,  0.00153371, -0.01885214], dtype=float32),
#  1686: array([ 0.00558597, -0.00317136, -0.0029862 , -0.01671391], dtype=float32),
#  1735: array([ 0.02080075, -0.01904936,  0.00912304, -0.00436722], dtype=float32),
#  1763: array([ 0.00748992,  0.00161026,  0.00791588, -0.01313136], dtype=float32),
#  1814: array([ 0.03479162, -0.04058698,  0.02341094, -0.01658645], dtype=float32),
#  1825: array([ 0.01342601, -0.00334408,  0.01328515, -0.01102773], dtype=float32),
#  1833: array([ 0.02396678, -0.0003221 ,  0.03106874, -0.02087956], dtype=float32),
#  1863: array([ 0.02797554, -0.03051449,  0.02134513, -0.01146705], dtype=float32),
#  1872: array([ 0.00665339, -0.00770783,  0.00108263, -0.00723674], dtype=float32),
#  1924: array([-0.00039377, -0.0062976 , -0.00996891, -0.00458321], dtype=float32),
#  1950: array([ 0.03476478, -0.03297201,  0.03627725, -0.0187094 ], dtype=float32),
#  1984: array([ 0.00947686, -0.04379383,  0.00774432, -0.00096823], dtype=float32),
#  1989: array([ 0.03089145, -0.04064256,  0.01708542, -0.01538187], dtype=float32),
#  2099: array([ 0.0207608 , -0.00982867,  0.00497362, -0.00838917], dtype=float32),
#  2146: array([ 0.01524996, -0.00145899,  0.01329417, -0.02028784], dtype=float32),
#  2156: array([ 0.02276347, -0.01895087,  0.03362075, -0.01840436], dtype=float32),
#  2184: array([ 0.02299601, -0.03079752,  0.01411638, -0.01577187], dtype=float32),
#  2219: array([ 0.02054039, -0.02100535,  0.02346961, -0.01675268], dtype=float32),
#  2242: array([ 0.0291793 , -0.03773938,  0.02785227, -0.01861189], dtype=float32),
#  2256: array([ 0.01415756, -0.05265245, -0.000309  ,  0.00146764], dtype=float32),
#  2398: array([ 0.02642568, -0.03516247,  0.03746074, -0.02217828], dtype=float32),
#  2401: array([ 0.0315652 , -0.03212193,  0.03832925, -0.02213427], dtype=float32),
#  2454: array([ 0.0161282 , -0.01830897,  0.00399003, -0.02007225], dtype=float32),
#  2520: array([ 0.03323247, -0.025432  ,  0.02355836, -0.0160633 ], dtype=float32),
#  2546: array([ 0.03404993, -0.03258837,  0.02737932, -0.01642511], dtype=float32),
#  2559: array([ 0.02623215, -0.03532839,  0.02850249, -0.01370618], dtype=float32),
#  2567: array([ 0.02667265, -0.04759273,  0.0359666 , -0.02688852], dtype=float32),
#  2663: array([ 0.02749249, -0.03437443,  0.01507334, -0.00810979], dtype=float32),
#  2741: array([-0.00641718, -0.00437347, -0.01638934, -0.00722756], dtype=float32),
#  2772: array([ 0.0256085 , -0.0360202 ,  0.0351171 , -0.01591646], dtype=float32),
#  2784: array([ 0.02530114, -0.05047077,  0.0362975 , -0.02375165], dtype=float32),
#  2814: array([ 0.03328302, -0.03981052,  0.02220717, -0.01918268], dtype=float32),
#  2836: array([ 0.0352612 , -0.05142777,  0.02713818, -0.01844333], dtype=float32),
#  2843: array([ 6.0365233e-03,  2.8979965e-05, -4.1524754e-03, -1.1706698e-02],
#        dtype=float32),
#  2856: array([ 0.00625338,  0.00206898,  0.00512788, -0.01639963], dtype=float32),
#  2949: array([ 0.01540643, -0.02180151,  0.00151497, -0.016023  ], dtype=float32),
#  2983: array([ 0.02307606, -0.04562693,  0.02973163, -0.02193269], dtype=float32),
#  2986: array([ 0.02187634, -0.04142377,  0.0368237 , -0.02304883], dtype=float32),
#  3003: array([ 0.03518113, -0.00578079,  0.02921396, -0.02165098], dtype=float32),
#  3005: array([ 0.02277311, -0.02260784,  0.01868697, -0.00718252], dtype=float32),
#  3060: array([ 0.01044534, -0.01687341, -0.01069377, -0.01001485], dtype=float32),
#  3194: array([ 0.02667416, -0.02543476,  0.0112729 , -0.00798059], dtype=float32),
#  3196: array([ 0.02062457, -0.02446298,  0.00462563, -0.0149887 ], dtype=float32),
#  3213: array([ 0.01145477, -0.01824413, -0.00462525, -0.00856891], dtype=float32),
#  3217: array([ 0.03111273, -0.02615151,  0.02801392, -0.02484125], dtype=float32),
#  3231: array([ 0.01430945, -0.05170624,  0.00345509, -0.00012136], dtype=float32),
#  3318: array([ 0.02356142, -0.04516835,  0.01236685, -0.00542373], dtype=float32),
#  3345: array([ 0.00842688,  0.0035455 ,  0.00911199, -0.01438417], dtype=float32),
#  3371: array([ 0.01915595, -0.01611517,  0.01664653, -0.01718793], dtype=float32),
#  3407: array([ 0.03601024, -0.03213048,  0.03180318, -0.01852031], dtype=float32),
#  3410: array([ 0.0372192 , -0.04419647,  0.03404741, -0.02017658], dtype=float32),
#  3411: array([ 0.01188657, -0.02359733,  0.0029142 , -0.02406232], dtype=float32),
#  3450: array([ 0.02641041, -0.0351388 ,  0.01817654, -0.02255684], dtype=float32),
#  3457: array([ 0.02602255, -0.01252776, -0.00112797, -0.01748051], dtype=float32),
#  3513: array([ 0.02944001, -0.04772697,  0.02652945, -0.02106977], dtype=float32),
#  3517: array([ 0.02487165, -0.04571183,  0.03473767, -0.02242841], dtype=float32),
#  3552: array([ 0.01343905, -0.01352734,  0.00501673, -0.01022169], dtype=float32),
#  3636: array([ 0.0050643 ,  0.01749516,  0.00981134, -0.01652499], dtype=float32),
#  3696: array([ 0.01793425, -0.02775942,  0.01039096, -0.00239846], dtype=float32),
#  3715: array([ 0.0153087 , -0.01157066,  0.00746958, -0.01633199], dtype=float32),
#  3717: array([ 0.0287991 , -0.03114072,  0.01317318, -0.00493785], dtype=float32),
#  3725: array([ 0.02620013, -0.0261021 ,  0.00039511, -0.01553383], dtype=float32),
#  3752: array([ 0.01961907, -0.00366871,  0.02380169, -0.02263812], dtype=float32),
#  3781: array([ 0.02264928,  0.00412691,  0.01247387, -0.02494497], dtype=float32),
#  3793: array([ 0.00221202, -0.00321102, -0.00138371, -0.00030126], dtype=float32),
#  3842: array([ 0.00450309, -0.00357929,  0.00365583, -0.00617026], dtype=float32),
#  3881: array([ 0.03054602, -0.03471522,  0.03544037, -0.02081163], dtype=float32),
#  3888: array([ 0.02603409, -0.0330813 ,  0.02255148, -0.01668609], dtype=float32),
#  3910: array([ 0.00520622, -0.00550668, -0.00954067, -0.00927741], dtype=float32),
#  3973: array([ 0.03822896, -0.0080747 ,  0.01216686, -0.01546085], dtype=float32),
#  3995: array([ 0.0266004 , -0.03273254,  0.02369037, -0.01685486], dtype=float32),
#  4002: array([ 0.0328897 , -0.02884497,  0.02515401, -0.02270536], dtype=float32),
#  4024: array([ 0.02963933, -0.04832885,  0.029787  , -0.02253869], dtype=float32),
#  4050: array([ 0.0291142 , -0.03103684,  0.02409843, -0.02027363], dtype=float32),
#  4068: array([ 0.02319035, -0.02343147,  0.01135392, -0.01613044], dtype=float32),
#  4086: array([ 0.02521414, -0.05058915,  0.03544516, -0.02358357], dtype=float32),
#  4267: array([ 0.01900512, -0.05932266, -0.00221617,  0.00126917], dtype=float32),
#  4310: array([ 0.02693291, -0.04346438,  0.01491371, -0.01777066], dtype=float32),
#  4350: array([ 0.02204011, -0.02174667,  0.01517001, -0.01152797], dtype=float32),
#  4366: array([ 0.03210212, -0.00235169,  0.03728577, -0.02745985], dtype=float32),
#  4422: array([ 0.00679003, -0.02179373, -0.01497844,  0.00034541], dtype=float32),
#  4423: array([ 0.01271588, -0.04876948,  0.00613953, -0.00093449], dtype=float32),
#  4441: array([ 0.02642997, -0.04991728,  0.03426338, -0.02431217], dtype=float32),
#  4466: array([ 0.01337112, -0.00411171,  0.01735901, -0.01718508], dtype=float32),
#  4505: array([ 0.040302  , -0.03435618,  0.02021533, -0.0152615 ], dtype=float32),
#  4534: array([ 0.00737789, -0.00024799,  0.00037456, -0.01745795], dtype=float32),
#  4548: array([ 0.01538007, -0.01594532,  0.03148628, -0.02763367], dtype=float32),
#  4578: array([ 0.01365979, -0.00545633, -0.00093938, -0.0142491 ], dtype=float32),
#  4592: array([ 0.03445641, -0.02403835,  0.02604605, -0.01091139], dtype=float32),
#  4684: array([ 0.0202186 ,  0.01076422,  0.00507372, -0.01934562], dtype=float32),
#  4702: array([ 0.03630157, -0.03088488,  0.02855565, -0.01761654], dtype=float32),
#  4706: array([ 0.01284538, -0.00829781, -0.00306236, -0.01221917], dtype=float32),
#  4718: array([ 0.02385528, -0.04016646,  0.02948418, -0.01380611], dtype=float32),
#  4730: array([ 0.02434361, -0.02919048,  0.00259837, -0.01439429], dtype=float32),
#  4737: array([ 0.0244581 , -0.01495322,  0.0244854 , -0.01938904], dtype=float32),
#  4792: array([ 0.02137715, -0.01728631,  0.01071404, -0.01940861], dtype=float32),
#  4794: array([ 0.02076686, -0.01856865,  0.01560122, -0.01697115], dtype=float32),
#  4847: array([ 0.03151389, -0.01738577,  0.01954239, -0.02761201], dtype=float32),
#  4889: array([ 0.03006992, -0.04696596,  0.03562252, -0.02297365], dtype=float32),
#  4896: array([ 0.00771083,  0.01540423,  0.01160819, -0.02273573], dtype=float32),
#  4970: array([ 0.01053828, -0.04138143,  0.01558618, -0.00699078], dtype=float32),
#  4999: array([ 0.01940979, -0.01747673,  0.01020884, -0.01828874], dtype=float32),
#  5065: array([ 0.0250382 , -0.00983303,  0.01032495, -0.0165289 ], dtype=float32),
#  5067: array([ 0.02414796, -0.0156036 ,  0.01322332, -0.01372191], dtype=float32),
#  5110: array([ 0.01988035, -0.02244806,  0.02600031, -0.01499889], dtype=float32),
#  5113: array([ 0.02594691, -0.02723227,  0.03286715, -0.0234958 ], dtype=float32),
#  5119: array([ 0.00020568, -0.00617875, -0.01138335, -0.00797009], dtype=float32),
#  5201: array([ 0.01799715, -0.00950934,  0.01923229, -0.01240476], dtype=float32),
#  5232: array([ 0.03251574, -0.04756762,  0.00909222, -0.01364452], dtype=float32),
#  5279: array([ 0.00590075,  0.00023906, -0.00569681, -0.01361201], dtype=float32),
#  5308: array([ 0.02434361, -0.02919048,  0.00259837, -0.01439429], dtype=float32),
#  5324: array([ 0.02175048, -0.02723124, -0.00355735, -0.008719  ], dtype=float32),
#  5372: array([ 0.00869196,  0.00186195,  0.00790703, -0.01309596], dtype=float32),
#  5377: array([ 0.03165052, -0.04758665,  0.02830948, -0.01926676], dtype=float32),
#  5403: array([ 0.01707283, -0.01963958,  0.0047119 , -0.02321953], dtype=float32),
#  5410: array([ 0.0201403 , -0.00475427,  0.00184176, -0.02354543], dtype=float32),
#  5516: array([ 0.01822278, -0.05554023,  0.00315207, -0.00113538], dtype=float32),
#  5536: array([ 0.02693399, -0.01973582, -0.00179884, -0.00052809], dtype=float32),
#  5555: array([ 0.02033822, -0.01131052,  0.00451145, -0.01017538], dtype=float32),
#  5640: array([ 0.02395844, -0.02286198,  0.02150151, -0.00532303], dtype=float32),
#  5688: array([ 0.00940957,  0.01646484,  0.01243994, -0.0234525 ], dtype=float32),
#  5705: array([ 0.02111973, -0.0186047 ,  0.01664248, -0.01716168], dtype=float32),
#  5799: array([ 0.02318701, -0.0306358 ,  0.02137639, -0.01904975], dtype=float32),
#  5842: array([ 0.0058856 , -0.01946183, -0.00314171, -0.01684589], dtype=float32),
#  5872: array([ 0.01533717, -0.04917989,  0.00861119, -0.00410092], dtype=float32),
#  5888: array([ 0.01587107, -0.04988712,  0.01478483, -0.00208588], dtype=float32),
#  5889: array([ 0.03712551, -0.02263755,  0.01933084, -0.00909201], dtype=float32),
#  5920: array([ 0.02932326, -0.03166568,  0.03257524, -0.01343972], dtype=float32),
#  6026: array([ 0.01920063, -0.01400748,  0.02182705, -0.01809691], dtype=float32),
#  6048: array([ 0.01116668, -0.0041313 ,  0.01772908, -0.02444769], dtype=float32),
#  6122: array([ 0.03589968, -0.04035208,  0.02260931, -0.01755474], dtype=float32),
#  6230: array([ 0.02242845, -0.02585897,  0.00182077, -0.01680754], dtype=float32),
#  6237: array([ 0.01129259,  0.01931887,  0.00555348, -0.03341188], dtype=float32),
#  6246: array([ 0.032821  , -0.03314749,  0.0324254 , -0.01950542], dtype=float32),
#  6250: array([ 0.01218567, -0.04574791,  0.0118407 , -0.00349823], dtype=float32),
#  6328: array([ 0.01213627,  0.00432351,  0.00880974, -0.01625264], dtype=float32),
#  6451: array([ 0.0176591 , -0.00642102,  0.01941764, -0.02423515], dtype=float32),
#  6482: array([ 0.01760054, -0.0313632 ,  0.01816863, -0.01944288], dtype=float32),
#  6537: array([ 0.02680512, -0.0201755 ,  0.01570459, -0.01511763], dtype=float32),
#  6553: array([ 0.02737005, -0.01667229,  0.01597372, -0.01931115], dtype=float32),
#  6555: array([ 0.03048169, -0.0302191 ,  0.01461683, -0.00679167], dtype=float32),
#  6628: array([ 0.01626874, -0.01060209,  0.01468411, -0.02017695], dtype=float32),
#  6662: array([ 0.01038399, -0.04093664,  0.01669159, -0.00679095], dtype=float32),
#  6678: array([ 0.00042236, -0.00816303, -0.0138239 , -0.00808261], dtype=float32),
#  6747: array([ 0.02111973, -0.0186047 ,  0.01664248, -0.01716168], dtype=float32),
#  6800: array([ 0.02252354, -0.0268388 ,  0.0036229 , -0.01468922], dtype=float32),
#  6806: array([ 0.01634427, -0.02735273,  0.03444798, -0.02798384], dtype=float32),
#  6859: array([ 0.02629121, -0.04426536,  0.0413206 , -0.02380572], dtype=float32),
#  6956: array([ 0.02482733, -0.04969497,  0.01760775, -0.01847442], dtype=float32),
#  7030: array([ 0.03056537, -0.04054331,  0.02269199, -0.01702468], dtype=float32),
#  7067: array([ 0.02380406, -0.00045418,  0.02623914, -0.02465926], dtype=float32),
#  7104: array([ 0.0131194 ,  0.00186381,  0.01322734, -0.02967778], dtype=float32),
#  7118: array([ 0.00428772,  0.01737697,  0.00649934, -0.01545109], dtype=float32),
#  7254: array([ 0.02863796, -0.02034981,  0.02490013, -0.02891576], dtype=float32),
#  7272: array([ 0.01235276, -0.02026396, -0.00889431, -0.00310416], dtype=float32),
#  7356: array([ 0.00615471, -0.01857263, -0.01508546,  0.00396511], dtype=float32),
#  7370: array([ 0.02699492, -0.00728006,  0.00481835, -0.00959814], dtype=float32),
#  7371: array([ 0.01691359, -0.01476876, -0.00207613, -0.0182272 ], dtype=float32),
#  7389: array([ 0.03387943, -0.04350954,  0.02680112, -0.0180847 ], dtype=float32),
#  7446: array([ 0.01707807, -0.00703938,  0.01465803, -0.01354115], dtype=float32),
#  7452: array([ 2.1136647e-02, -2.4653548e-02,  4.6921195e-05, -7.9759490e-03],
#        dtype=float32),
#  7491: array([ 0.01752066, -0.04601145,  0.01046666, -0.01506812], dtype=float32),
#  7493: array([ 0.01042954,  0.00973426,  0.01559338, -0.02136431], dtype=float32),
#  7509: array([ 0.01542005, -0.0129834 ,  0.01213595, -0.01881571], dtype=float32),
#  7552: array([ 0.0179009 , -0.05459877,  0.00413613, -0.00161674], dtype=float32),
#  7631: array([ 0.03429771, -0.03395277,  0.02204637, -0.02104182], dtype=float32),
#  7634: array([ 0.03397913, -0.04161771,  0.01599343, -0.01655667], dtype=float32),
#  7638: array([ 0.01542627, -0.02398421,  0.02673621, -0.01729733], dtype=float32),
#  7689: array([ 0.02925269, -0.04008332,  0.03193231, -0.02035947], dtype=float32),
#  7777: array([ 0.01295058, -0.00124749,  0.00763107, -0.01673585], dtype=float32),
#  7798: array([ 0.01528847, -0.01500699,  0.01048198, -0.01747338], dtype=float32),
#  7826: array([ 0.03533756, -0.02747057,  0.01766427, -0.01635802], dtype=float32),
#  7854: array([ 0.02650797, -0.02633985,  0.03706012, -0.0216708 ], dtype=float32),
#  7896: array([ 0.01974579, -0.01259486,  0.01959477, -0.01273829], dtype=float32),
#  7918: array([ 0.02237039, -0.03901156,  0.0103625 , -0.01102128], dtype=float32),
#  7930: array([ 0.03936571, -0.04200916,  0.01961437, -0.01481246], dtype=float32),
#  7983: array([ 0.02392117, -0.02948923,  0.00143938, -0.01419275], dtype=float32),
#  8010: array([ 0.01746365, -0.03118338,  0.00628962, -0.00173996], dtype=float32),
#  8015: array([ 0.00940431,  0.01292952,  0.01384502, -0.02038146], dtype=float32),
#  8072: array([ 0.00110381, -0.0039178 , -0.01159765, -0.01077682], dtype=float32),
#  8123: array([ 0.01450527,  0.00579176,  0.00508417, -0.02177225], dtype=float32),
#  8134: array([ 0.0120889 ,  0.00266095,  0.00482079, -0.02199449], dtype=float32),
#  8156: array([ 0.01668998, -0.0317874 ,  0.0381402 , -0.02773571], dtype=float32),
#  8206: array([ 0.0223848 , -0.01476126,  0.02372548, -0.02040776], dtype=float32),
#  8219: array([ 0.01783635, -0.01916067,  0.00893624, -0.01593166], dtype=float32),
#  8278: array([ 0.0212053 , -0.01982185,  0.01720002, -0.01189955], dtype=float32),
#  8365: array([ 0.0320512 , -0.01877763,  0.02834292, -0.01789716], dtype=float32),
#  8373: array([ 0.02014857, -0.04477586,  0.0362806 , -0.02385047], dtype=float32),
#  8410: array([ 0.02363112, -0.02492237,  0.01864629, -0.02275631], dtype=float32),
#  8430: array([ 0.02567353, -0.02833476,  0.00704816, -0.01522172], dtype=float32),
#  8506: array([ 0.02434361, -0.02919048,  0.00259837, -0.01439429], dtype=float32),
#  8510: array([ 0.03473361, -0.02843583,  0.0106279 , -0.01422824], dtype=float32),
#  8517: array([ 0.01200502, -0.01569005, -0.01498248,  0.01336962], dtype=float32),
#  8522: array([ 0.02328933, -0.01953486,  0.02195299, -0.01933083], dtype=float32),
#  8523: array([ 0.02764575, -0.03586049,  0.02264995, -0.02397682], dtype=float32),
#  8581: array([ 0.01104921, -0.00523083,  0.00741997, -0.00403074], dtype=float32),
#  8693: array([ 0.01896713, -0.03754441,  0.0092319 , -0.01099312], dtype=float32),
#  8750: array([ 0.03377941, -0.03154857,  0.02241391, -0.02235433], dtype=float32),
#  8882: array([ 0.01135217, -0.0013728 ,  0.0008786 , -0.01719818], dtype=float32),
#  8894: array([ 0.01049913, -0.02892923,  0.01947877, -0.0117404 ], dtype=float32),
#  8966: array([ 0.02101792, -0.04109716,  0.02538617, -0.0201529 ], dtype=float32),
#  9009: array([ 0.03601683, -0.04296477,  0.0212019 , -0.01612164], dtype=float32),
#  9042: array([ 0.02127094, -0.0320772 ,  0.01994153, -0.00601406], dtype=float32),
#  9086: array([ 0.01817462, -0.01809592,  0.0080508 , -0.01805405], dtype=float32),
#  9089: array([ 0.00359433,  0.02584298,  0.00475006, -0.02226961], dtype=float32),
#  9111: array([ 0.02786847, -0.03047876,  0.02104386, -0.02237488], dtype=float32),
#  9129: array([ 0.02664763, -0.01639603,  0.01992207, -0.0140968 ], dtype=float32),
#  9144: array([ 0.03266109, -0.02243641,  0.01737612, -0.02112783], dtype=float32),
#  9164: array([ 0.00933368, -0.01090966, -0.00095894, -0.00554972], dtype=float32),
#  9165: array([ 0.0326857 , -0.0278183 ,  0.03547581, -0.01802253], dtype=float32),
#  9202: array([ 0.00951453, -0.04320685,  0.01028924, -0.00205283], dtype=float32),
#  9214: array([ 0.02857036, -0.03114902,  0.01876321, -0.01667959], dtype=float32),
#  9230: array([ 0.0133636 , -0.02183618,  0.00738191, -0.00572622], dtype=float32),
#  9231: array([ 0.017605  , -0.01592314, -0.00250512, -0.01755522], dtype=float32),
#  9265: array([ 0.02962708, -0.02220329,  0.04122641, -0.02275666], dtype=float32),
#  9329: array([ 0.00403842, -0.03021361,  0.0263469 , -0.01059734], dtype=float32),
#  9336: array([ 0.02109544, -0.0335811 ,  0.03382135, -0.02365674], dtype=float32),
#  9376: array([ 0.02154129, -0.03737045,  0.03095427, -0.02100136], dtype=float32),
#  9377: array([ 0.00599099,  0.00491158,  0.00815737, -0.01683062], dtype=float32),
#  9410: array([ 0.01009757, -0.00397549,  0.0063227 , -0.00741356], dtype=float32),
#  9444: array([ 0.02733654, -0.03249404,  0.02104748, -0.01992627], dtype=float32),
#  9456: array([ 0.01832163, -0.01341858, -0.00152145, -0.01891834], dtype=float32),
#  9472: array([ 0.02188937, -0.01429705,  0.02752869, -0.02987855], dtype=float32),
#  9479: array([ 0.01963952, -0.0183349 ,  0.00768542, -0.01909818], dtype=float32),
#  9528: array([ 0.01832043, -0.02582911, -0.00020759, -0.01425425], dtype=float32),
#  9592: array([ 0.01818811, -0.00922301,  0.02514467, -0.01860164], dtype=float32),
#  9622: array([ 0.0156393 , -0.05230792,  0.00538385, -0.00132989], dtype=float32),
#  9645: array([-0.00087387,  0.00442602, -0.01202786, -0.01083353], dtype=float32),
#  9681: array([ 0.02482291, -0.01441275,  0.02321643, -0.01475828], dtype=float32),
#  9699: array([ 0.00835306, -0.01762796, -0.00350347, -0.01045352], dtype=float32),
#  9721: array([ 0.01762341, -0.01974394, -0.00433917, -0.00225154], dtype=float32),
#  9783: array([ 0.00881137, -0.0383874 ,  0.01947633, -0.00693641], dtype=float32),
#  9857: array([ 0.01491485, -0.0487215 ,  0.00960066, -0.00396359], dtype=float32),
#  9927: array([ 0.02220843, -0.05058005,  0.01480949, -0.00704924], dtype=float32),
#  9976: array([ 0.01432111,  0.00240708,  0.01679333, -0.02139581], dtype=float32),
#  10026: array([ 0.02186287, -0.04155639,  0.03625969, -0.02270626], dtype=float32),
#  10064: array([ 0.0303139 , -0.01293416,  0.03153709, -0.02312973], dtype=float32),
#  10143: array([ 0.02001377, -0.05145971,  0.02671269, -0.02242402], dtype=float32),
#  10232: array([ 0.0131704 , -0.01916524,  0.00934708, -0.00768572], dtype=float32),
#  10259: array([ 0.01847554, -0.04258544,  0.03740637, -0.02410618], dtype=float32),
#  10300: array([ 0.02206592, -0.04771442,  0.02692275, -0.02122908], dtype=float32),
#  10460: array([ 0.02204629, -0.02928094,  0.03776217, -0.02825668], dtype=float32),
#  10480: array([ 0.0159382 , -0.01785074,  0.01461316, -0.01744829], dtype=float32),
#  10527: array([ 0.01887718, -0.04238724,  0.01823756, -0.02480204], dtype=float32),
#  10663: array([ 0.02653115, -0.05215472,  0.02298928, -0.0214393 ], dtype=float32),
#  10665: array([ 0.02123564, -0.00116587,  0.01134955, -0.02353552], dtype=float32),
#  10674: array([ 0.02490564, -0.04490697,  0.02444134, -0.02067097], dtype=float32),
#  10697: array([ 0.01315996, -0.04497356,  0.01873151, -0.02165165], dtype=float32),
#  10708: array([ 0.03992646, -0.01427111,  0.02200102, -0.01845111], dtype=float32),
#  10749: array([ 0.03192807, -0.05172733,  0.01788311, -0.01782651], dtype=float32),
#  10753: array([ 0.02321783, -0.04737451,  0.03600393, -0.01779473], dtype=float32),
#  10775: array([ 0.03308615, -0.04600872,  0.02828755, -0.01960126], dtype=float32),
#  10837: array([ 0.0154789 , -0.02348064,  0.03782092, -0.02899132], dtype=float32),
#  10870: array([ 0.02124842, -0.02679174, -0.00046222, -0.01650134], dtype=float32),
#  10980: array([ 0.01596232, -0.01995065,  0.0053633 , -0.01544806], dtype=float32),
#  10996: array([ 0.03530722, -0.02473726,  0.02886507, -0.01700535], dtype=float32),
#  11039: array([ 0.017066  , -0.01192698,  0.01071822, -0.0220186 ], dtype=float32),
#  11084: array([ 0.01778278,  0.00550311,  0.00641922, -0.02782245], dtype=float32),
#  11114: array([ 0.02282562, -0.02107318,  0.02239195, -0.01948473], dtype=float32),
#  11121: array([ 0.03094043, -0.02550414,  0.02270453, -0.01829796], dtype=float32),
#  11129: array([ 0.02062457, -0.02446298,  0.00462563, -0.0149887 ], dtype=float32),
#  11138: array([ 0.01897613, -0.02074452,  0.01922654, -0.00487768], dtype=float32),
#  11152: array([ 0.01633702,  0.00663398,  0.01316776, -0.00984951], dtype=float32),
#  11154: array([ 0.02339421, -0.02634882,  0.00591404, -0.01507873], dtype=float32),
#  11206: array([ 0.01047792, -0.00957513, -0.00379822, -0.01180007], dtype=float32),
#  11210: array([ 0.02142846, -0.01867962,  0.01766244, -0.01735844], dtype=float32),
#  11286: array([ 0.01601758, -0.04712672,  0.02881905, -0.02308704], dtype=float32),
#  11326: array([ 0.02523107, -0.06241285,  0.02805643, -0.02306069], dtype=float32),
#  11332: array([ 0.0179009 , -0.05459877,  0.00413613, -0.00161674], dtype=float32),
#  11363: array([-0.00118761,  0.00258042, -0.00186582, -0.00736608], dtype=float32),
#  11392: array([ 0.01462062, -0.04798292,  0.00941906, -0.00462251], dtype=float32),
#  11447: array([ 0.02039992, -0.03022606,  0.02065753, -0.02459146], dtype=float32),
#  11450: array([ 0.02931911,  0.00261126,  0.02453261, -0.01553398], dtype=float32),
#  11481: array([ 0.02265713, -0.06205949,  0.01415677, -0.01359806], dtype=float32),
#  11488: array([ 0.03117244, -0.03555209,  0.03598746, -0.02044362], dtype=float32),
#  11500: array([ 0.00717708, -0.01529483,  0.00181462, -0.01733304], dtype=float32),
#  11514: array([ 0.00011656, -0.00779412, -0.01152771, -0.00539418], dtype=float32),
#  11553: array([ 0.01147914, -0.02236012,  0.02644901, -0.03217242], dtype=float32),
#  11554: array([ 0.01983571, -0.02410514,  0.03783421, -0.02828356], dtype=float32),
#  11575: array([ 0.02520052, -0.02067645,  0.01470194, -0.01884589], dtype=float32),
#  11591: array([ 0.0266127 , -0.05311471,  0.04480515, -0.02555504], dtype=float32),
#  11626: array([ 0.01523881, -0.05075546,  0.00750932, -0.0023212 ], dtype=float32),
#  11666: array([ 0.00861728, -0.00669308, -0.00075709, -0.0122858 ], dtype=float32),
#  11680: array([ 0.01945088, -0.02186908,  0.01611345, -0.02121575], dtype=float32),
#  11681: array([ 0.00473963,  0.01422264, -0.00286513, -0.02016068], dtype=float32),
#  11740: array([ 0.02406178, -0.01665948,  0.00949384, -0.02155005], dtype=float32),
#  11755: array([ 0.0275245 , -0.03444773,  0.03901469, -0.02154506], dtype=float32),
#  11801: array([ 0.02043148, -0.02821027, -0.00116416, -0.01391797], dtype=float32),
#  11833: array([ 0.03246223, -0.03082719,  0.03089994, -0.02014587], dtype=float32),
#  11857: array([ 0.01222382, -0.02294931,  0.04021453, -0.03213943], dtype=float32),
#  11867: array([ 0.0220403 , -0.02713434,  0.00245072, -0.01449669], dtype=float32),
#  11889: array([ 0.0237907 , -0.01546792,  0.00488915, -0.00613676], dtype=float32),
#  11891: array([ 0.01042767, -0.02231302,  0.00539989,  0.00468225], dtype=float32),
#  11903: array([ 0.02160389, -0.05097813,  0.02140814, -0.02605132], dtype=float32),
#  11953: array([ 0.0154789 , -0.02348064,  0.03782092, -0.02899132], dtype=float32),
#  11959: array([ 0.0165201 , -0.01072638,  0.01294533, -0.01131205], dtype=float32),
#  11986: array([ 0.00617123, -0.00630094,  0.00162721, -0.00222618], dtype=float32),
#  12026: array([ 0.02090093, -0.04741183,  0.02433468, -0.02115356], dtype=float32),
#  12089: array([ 0.00748992,  0.00161026,  0.00791588, -0.01313136], dtype=float32),
#  12108: array([ 0.02322505, -0.027295  ,  0.01436371, -0.01729604], dtype=float32),
#  12136: array([ 0.01659528, -0.02394329,  0.01095309, -0.00571021], dtype=float32),
#  12246: array([ 0.01080552,  0.0029788 ,  0.01212261, -0.0239788 ], dtype=float32),
#  12285: array([ 0.00926362, -0.03935794,  0.01854907, -0.00640826], dtype=float32),
#  12304: array([ 0.0221727 , -0.02738974,  0.0184181 , -0.00376635], dtype=float32),
#  12368: array([ 0.02978763, -0.04503219,  0.0181489 , -0.01181267], dtype=float32),
#  12403: array([ 0.02975528, -0.03289114,  0.02562314, -0.01466134], dtype=float32),
#  12467: array([ 0.03015641, -0.03282303,  0.04127198, -0.02079693], dtype=float32),
#  12492: array([ 0.01443435, -0.00233983, -0.00033949, -0.01810736], dtype=float32),
#  12493: array([ 0.03419025, -0.03598556,  0.02421714, -0.01898783], dtype=float32),
#  12613: array([ 0.01491457,  0.00890835,  0.01898509, -0.02490679], dtype=float32),
#  12643: array([ 0.01855925, -0.02790133,  0.01609576, -0.01703099], dtype=float32),
#  12694: array([ 0.02000758, -0.02248601,  0.02590554, -0.01700083], dtype=float32),
#  12748: array([ 0.02152742, -0.03169174,  0.0272467 , -0.01185213], dtype=float32),
#  12836: array([ 0.01829193, -0.03657165,  0.03624518, -0.02797264], dtype=float32),
#  12866: array([ 0.0255044 , -0.02816976,  0.02776345, -0.00683668], dtype=float32),
#  12931: array([ 0.01271238, -0.02960698,  0.01121061, -0.00884066], dtype=float32),
#  12935: array([ 0.02156255, -0.00920254,  0.02066301, -0.02167244], dtype=float32),
#  12958: array([ 0.01568399, -0.05554906, -0.00298247,  0.00225595], dtype=float32),
#  12980: array([ 0.01913487, -0.01384089,  0.00976057, -0.02180211], dtype=float32),
#  13017: array([ 0.02169043, -0.02877462,  0.0034662 , -0.01635923], dtype=float32),
#  13074: array([ 0.01505534,  0.01219246,  0.01323391, -0.03103334], dtype=float32),
#  13083: array([ 0.03842056, -0.04655306,  0.01859506, -0.01715207], dtype=float32),
#  13086: array([ 0.01746073, -0.02688142,  0.02352457, -0.01820295], dtype=float32),
#  13101: array([ 0.01686964, -0.05360599,  0.00482214, -0.00148538], dtype=float32),
#  13180: array([ 0.03227029, -0.03567612,  0.03809999, -0.02055174], dtype=float32),
#  13185: array([ 0.01746157, -0.0570219 , -0.00070608,  0.00097122], dtype=float32),
#  13313: array([ 0.02690321, -0.05168584,  0.02397577, -0.02157902], dtype=float32),
#  13370: array([ 0.03082282, -0.02645247,  0.03222964, -0.02134305], dtype=float32),
#  13372: array([ 0.02431133, -0.01595221,  0.02032349, -0.02089052], dtype=float32),
#  13381: array([ 0.02432452, -0.01074974,  0.03425395, -0.02979222], dtype=float32),
#  13410: array([ 0.03231062, -0.01998347,  0.03548151, -0.02517862], dtype=float32),
#  13438: array([ 0.02640269, -0.02144919,  0.03050723, -0.0234354 ], dtype=float32),
#  13439: array([ 0.0188724 , -0.00603059,  0.01407136, -0.01717434], dtype=float32),
#  13570: array([ 0.02669092, -0.02458618,  0.01844698, -0.02721565], dtype=float32),
#  13598: array([ 0.01606834, -0.00777951, -0.00205707, -0.00848746], dtype=float32),
#  13619: array([ 0.00965989, -0.04028743,  0.01759114, -0.00588584], dtype=float32),
#  13639: array([ 0.01995114, -0.01765148,  0.01123237, -0.01018975], dtype=float32),
#  13661: array([ 0.01548481, -0.00602036,  0.01582129, -0.01615254], dtype=float32),
#  13737: array([ 0.028147  , -0.03979301,  0.04212244, -0.02395773], dtype=float32),
#  13750: array([ 0.03277159, -0.01380427,  0.03136807, -0.02221908], dtype=float32),
#  13804: array([ 0.02708618, -0.0321889 ,  0.01756973, -0.02322932], dtype=float32),
#  13837: array([-0.00143877,  0.01125443,  0.00486805, -0.01167762], dtype=float32),
#  13843: array([ 0.02555058, -0.01805085,  0.01157878, -0.02055992], dtype=float32),
#  13943: array([ 0.0179009 , -0.05459877,  0.00413613, -0.00161674], dtype=float32),
#  13953: array([ 0.00887532, -0.00763463, -0.00135003, -0.01163228], dtype=float32),
#  13969: array([ 0.00625338,  0.00206898,  0.00512788, -0.01639963], dtype=float32),
#  14071: array([ 0.02883293, -0.0220563 ,  0.01986118, -0.02238867], dtype=float32),
#  14085: array([ 0.01382965, -0.0486713 ,  0.00915006, -0.00265962], dtype=float32),
#  14173: array([ 0.03454667, -0.04324239,  0.02257678, -0.01978626], dtype=float32),
#  14251: array([ 0.02485486, -0.02140609,  0.00860825, -0.01897283], dtype=float32),
#  14271: array([ 0.01793986, -0.01631624,  0.00480898, -0.01119755], dtype=float32),
#  14275: array([ 0.02241868, -0.02051893,  0.00915982, -0.02079026], dtype=float32),
#  14284: array([ 0.02320428, -0.01976106,  0.03724243, -0.03091866], dtype=float32),
#  14323: array([ 0.02307312,  0.00151871,  0.00938077, -0.02455738], dtype=float32),
#  14326: array([ 0.00934263, -0.0058693 ,  0.00947754, -0.01333974], dtype=float32),
#  14333: array([ 0.00555286,  0.00911017,  0.00132884, -0.01596407], dtype=float32),
#  14389: array([ 0.02971265, -0.04369811,  0.01746058, -0.01898601], dtype=float32),
#  14448: array([ 0.03006656, -0.04545721,  0.01816897, -0.01758069], dtype=float32),
#  14462: array([ 0.02273888, -0.02653023,  0.01862573, -0.0222464 ], dtype=float32),
#  14488: array([ 0.03394905, -0.0488912 ,  0.02411045, -0.018741  ], dtype=float32),
#  14635: array([ 0.03573285, -0.03238624,  0.01341954, -0.0168269 ], dtype=float32),
#  14640: array([ 0.012918  , -0.01516279,  0.00309211, -0.00878985], dtype=float32),
#  14735: array([ 0.03486385, -0.03645893,  0.01336477, -0.01332561], dtype=float32),
#  14752: array([ 0.0237526 , -0.02561376,  0.01106717, -0.01072154], dtype=float32),
#  14771: array([ 0.03294811, -0.03704749,  0.01373194, -0.01473687], dtype=float32),
#  14800: array([ 0.02035089, -0.01183985,  0.00426625, -0.01552881], dtype=float32),
#  14803: array([ 0.02814563, -0.03188056,  0.02699517, -0.01736405], dtype=float32),
#  14812: array([ 0.01799442, -0.02063242, -0.0011706 , -0.01167706], dtype=float32),
#  14816: array([ 0.00232672, -0.03898656,  0.02362768, -0.01427199], dtype=float32),
#  14831: array([ 0.03174875, -0.04385572,  0.02949229, -0.01983025], dtype=float32),
#  14857: array([ 0.03635645, -0.02920881,  0.03285882, -0.01685788], dtype=float32),
#  14877: array([ 0.02172645, -0.02238026,  0.01897105, -0.02396353], dtype=float32),
#  14906: array([ 0.01234087, -0.01479115,  0.0084416 , -0.0162694 ], dtype=float32),
#  14960: array([ 0.01614757, -0.0269743 , -0.00874822, -0.0065697 ], dtype=float32),
#  15067: array([ 0.02379546, -0.02839727,  0.00521365, -0.00438675], dtype=float32),
#  15101: array([ 0.02910398, -0.03077766,  0.02395027, -0.01737054], dtype=float32),
#  15116: array([ 0.02263187, -0.00793394,  0.00312743, -0.02029914], dtype=float32),
#  15169: array([ 0.01269155, -0.00186015,  0.00864407, -0.02234496], dtype=float32),
#  15187: array([ 0.02434658, -0.01588789,  0.01968183, -0.02074337], dtype=float32),
#  15217: array([ 0.00328043, -0.01475159,  0.00802282, -0.01941394], dtype=float32),
#  15227: array([ 0.01931199,  0.00629892,  0.01679698, -0.02428054], dtype=float32),
#  15239: array([ 0.00043816, -0.01022124, -0.00032227, -0.00624989], dtype=float32),
#  15250: array([ 0.03133603, -0.0343228 ,  0.02301626, -0.02310839], dtype=float32),
#  15268: array([ 0.00994591, -0.00056126,  0.00268221, -0.01626711], dtype=float32),
#  15281: array([ 0.01434375, -0.01739582,  0.00571652, -0.01658334], dtype=float32),
#  15306: array([ 0.02938859, -0.01512202, -0.00219751, -0.01447739], dtype=float32),
#  15334: array([ 0.01601758, -0.04712672,  0.02881905, -0.02308704], dtype=float32),
#  15383: array([ 0.02917743, -0.03498243,  0.01048334, -0.01066409], dtype=float32),
#  15467: array([ 0.03601683, -0.04296477,  0.0212019 , -0.01612164], dtype=float32),
#  15477: array([ 0.02412636, -0.02660544,  0.01794803, -0.0037424 ], dtype=float32),
#  15487: array([ 0.01379074, -0.00721689, -0.00477832, -0.01637819], dtype=float32),
#  15536: array([ 0.0301737 , -0.05143142,  0.0325188 , -0.02195979], dtype=float32),
#  15675: array([ 0.00884151,  0.00050524,  0.00605261, -0.01393264], dtype=float32),
#  15738: array([ 0.02757458, -0.04243301,  0.01044993, -0.00886436], dtype=float32),
#  15824: array([ 0.02562199, -0.04049439,  0.03359498, -0.02274319], dtype=float32),
#  15838: array([ 0.00665839, -0.03445669,  0.02306403, -0.00834062], dtype=float32),
#  15907: array([ 0.01483595, -0.01893313, -0.00539221, -0.00091535], dtype=float32),
#  15911: array([ 0.01989761, -0.02035102,  0.0029703 , -0.0096803 ], dtype=float32),
#  15915: array([ 0.0167213 , -0.0439919 ,  0.02053809, -0.02708447], dtype=float32),
#  15936: array([ 0.02729519, -0.03540178,  0.03010911, -0.02085048], dtype=float32),
#  15995: array([ 0.02097503, -0.04191758,  0.04303439, -0.02480999], dtype=float32),
#  16008: array([ 0.00923776, -0.00954245, -0.00018516, -0.022898  ], dtype=float32),
#  16011: array([ 0.02511891, -0.04901286,  0.02937842, -0.0217268 ], dtype=float32),
#  16015: array([ 0.02347243, -0.02747465,  0.00220063, -0.0155693 ], dtype=float32),
#  16021: array([ 0.01495973, -0.04989132,  0.00852662, -0.00281782], dtype=float32),
#  16071: array([ 0.0228498 , -0.011018  ,  0.01019024, -0.01532455], dtype=float32),
#  16117: array([ 0.03505231, -0.04011323,  0.02626879, -0.01727324], dtype=float32),
#  16119: array([ 0.03476737, -0.02757608,  0.03387866, -0.01980309], dtype=float32),
#  16131: array([ 0.00078557, -0.03343448,  0.01227937, -0.01785074], dtype=float32),
#  16174: array([ 0.01818811, -0.00922301,  0.02514467, -0.01860164], dtype=float32),
#  16204: array([ 0.01898347, -0.06033973, -0.0045693 ,  0.00225483], dtype=float32),
#  16216: array([ 0.01797613,  0.00693857,  0.01887919, -0.02359441], dtype=float32),
#  16222: array([ 0.02796032, -0.03855108,  0.01144604, -0.00849628], dtype=float32),
#  16259: array([ 0.01423562, -0.00284265,  0.02163698, -0.02446984], dtype=float32),
#  16262: array([ 0.03834538, -0.01778183,  0.02754164, -0.02263433], dtype=float32),
#  16280: array([ 0.03054597, -0.01999686,  0.01863706, -0.02641979], dtype=float32),
#  16338: array([ 0.03030594, -0.04598615,  0.02983275, -0.02204025], dtype=float32),
#  16364: array([ 0.03304347, -0.04645737,  0.03216779, -0.02079435], dtype=float32),
#  16377: array([ 0.03345997, -0.02744988,  0.02899153, -0.01828865], dtype=float32),
#  16517: array([ 0.02604805, -0.055339  ,  0.0203138 , -0.0198476 ], dtype=float32),
#  16520: array([ 0.0132498 ,  0.0060678 ,  0.01019981, -0.01739513], dtype=float32),
#  16537: array([ 0.01414978, -0.05008672,  0.00696139, -0.00165348], dtype=float32),
#  16562: array([ 0.01461371, -0.01798251,  0.00417547, -0.01896971], dtype=float32),
#  16659: array([ 0.00061184, -0.01098612, -0.01454065, -0.0049111 ], dtype=float32),
#  16677: array([ 0.0200313 , -0.0149459 ,  0.00243029, -0.01355959], dtype=float32),
#  16718: array([ 0.01824456,  0.00843687,  0.01966707, -0.02309691], dtype=float32),
#  16734: array([ 0.01697205, -0.01095419,  0.01734055, -0.01120354], dtype=float32),
#  16760: array([ 0.02679841, -0.0282194 ,  0.00319387, -0.0017362 ], dtype=float32),
#  16761: array([ 0.01926918, -0.01535063,  0.01221088, -0.00328079], dtype=float32),
#  16769: array([ 0.02266704, -0.02363003,  0.00178058, -0.00690711], dtype=float32),
#  16807: array([ 0.01686414, -0.02655792, -0.0076003 , -0.00673703], dtype=float32),
#  16817: array([ 0.00207069,  0.01887056,  0.00624288, -0.01775458], dtype=float32),
#  16837: array([ 0.02212122, -0.01897953,  0.02434742, -0.01162974], dtype=float32),
#  16838: array([ 0.02746579, -0.02406794,  0.03187378, -0.01982775], dtype=float32),
#  16882: array([ 0.00845826, -0.00219289, -0.00439216, -0.01859804], dtype=float32),
#  16899: array([ 0.00657233, -0.00652029,  0.01300948, -0.02456756], dtype=float32),
#  16932: array([ 0.01521882,  0.00790588,  0.01032603, -0.03044125], dtype=float32),
#  16959: array([ 0.02207752, -0.04989687,  0.0309782 , -0.0229446 ], dtype=float32),
#  16960: array([ 0.03757906, -0.03165733,  0.03333693, -0.0171759 ], dtype=float32),
#  17027: array([ 0.02409866, -0.0278388 ,  0.02203801, -0.01048356], dtype=float32),
#  17098: array([ 0.0113511 ,  0.01882746,  0.01622181, -0.02381497], dtype=float32),
#  17099: array([ 0.02481373, -0.02126982,  0.03437094, -0.02518808], dtype=float32),
#  17106: array([ 0.03198573, -0.04908417,  0.02929099, -0.02082367], dtype=float32),
#  17115: array([ 0.02962079, -0.03454185,  0.01951992, -0.01008119], dtype=float32),
#  17118: array([ 0.01974377, -0.00881293,  0.00745859, -0.01612784], dtype=float32),
#  17172: array([ 0.01491485, -0.0487215 ,  0.00960066, -0.00396359], dtype=float32),
#  17219: array([ 0.01392452, -0.01139896, -0.00179795,  0.00468072], dtype=float32),
#  17232: array([ 0.04187703, -0.036224  ,  0.02101791, -0.01550824], dtype=float32),
#  17280: array([ 0.02678063, -0.03462787,  0.03396793, -0.0217876 ], dtype=float32),
#  17324: array([ 0.02106523, -0.0118674 ,  0.00461455, -0.00922053], dtype=float32),
#  17332: array([ 0.02652044, -0.02712616,  0.00575615, -0.01637312], dtype=float32),
#  17383: array([ 0.02209997, -0.020484  ,  0.00359314, -0.01091679], dtype=float32),
#  17399: array([ 0.03570308, -0.01167383,  0.03293415, -0.02035999], dtype=float32),
#  17429: array([ 0.03120334, -0.04842906,  0.03871326, -0.02319503], dtype=float32),
#  17496: array([ 0.02662347, -0.02601149,  0.02528413, -0.01864697], dtype=float32),
#  17512: array([-0.00012011,  0.0112208 ,  0.00339369, -0.01317979], dtype=float32),
#  17550: array([ 0.01655615, -0.01175773,  0.01695111, -0.01832855], dtype=float32),
#  17576: array([ 0.0181486 , -0.04108951,  0.01857728, -0.02543513], dtype=float32),
#  17612: array([ 0.02993271, -0.04646101,  0.02608218, -0.01888782], dtype=float32),
#  17638: array([ 0.01185731, -0.00848329,  0.01152398, -0.02246499], dtype=float32),
#  17682: array([ 0.01816839, -0.02198608,  0.01743929, -0.00350586], dtype=float32),
#  17725: array([ 0.00454748,  0.01097772,  0.00529682, -0.01399532], dtype=float32),
#  17790: array([ 0.02809648, -0.02521856,  0.03093081, -0.02120706], dtype=float32),
#  17793: array([ 0.0295701 , -0.03626247,  0.0130629 , -0.01752438], dtype=float32),
#  17843: array([ 0.0144544 , -0.00830614,  0.01836516, -0.01189869], dtype=float32),
#  17880: array([ 0.02539945, -0.02849652,  0.0059649 , -0.0150104 ], dtype=float32),
#  17975: array([ 0.00693354,  0.02038346,  0.00918431, -0.01974872], dtype=float32),
#  17995: array([ 0.00930092, -0.00879838,  0.00168821, -0.0021683 ], dtype=float32),
#  18022: array([ 0.02278352, -0.04146108,  0.01538933, -0.02332074], dtype=float32),
#  18035: array([ 0.01358071, -0.03150237,  0.01741498, -0.02358293], dtype=float32),
#  18075: array([ 0.01114956,  0.00730666,  0.01808083, -0.0242908 ], dtype=float32),
#  18079: array([ 0.02745615, -0.01069234,  0.00838259, -0.02080281], dtype=float32),
#  18090: array([ 0.03184914, -0.03363354,  0.03535554, -0.01919049], dtype=float32),
#  18172: array([ 0.03321804, -0.03342791,  0.02718013, -0.01950518], dtype=float32),
#  18175: array([ 0.00949449, -0.04280391,  0.01151932, -0.00258455], dtype=float32),
#  18284: array([ 0.02921884, -0.03031399,  0.02891299, -0.01214636], dtype=float32),
#  18327: array([ 0.03540177, -0.02672327,  0.02485374, -0.02304148], dtype=float32),
#  18393: array([ 0.01699119, -0.03646246,  0.03221856, -0.02734317], dtype=float32),
#  18422: array([ 0.02520635, -0.03012008,  0.02586513, -0.01731759], dtype=float32),
#  18428: array([ 0.0204366 , -0.04683056,  0.00780689, -0.00511307], dtype=float32),
#  18548: array([ 0.02426193, -0.01886707,  0.02052764, -0.02003092], dtype=float32),
#  18571: array([ 0.02856918, -0.04603823,  0.02277481, -0.01347764], dtype=float32),
#  18579: array([ 0.02277773, -0.02823203,  0.02001369, -0.01016388], dtype=float32),
#  18632: array([ 0.00596081,  0.00728832,  0.00688637, -0.01937404], dtype=float32),
#  18639: array([ 0.01921286, -0.03040893,  0.00831901, -0.00203195], dtype=float32),
#  18654: array([ 0.0223008 , -0.01186846,  0.02282009, -0.02107266], dtype=float32),
#  18660: array([ 0.01575316, -0.0137806 ,  0.01434009, -0.01695764], dtype=float32),
#  18691: array([ 0.00859917, -0.00481709,  0.00217004, -0.00998438], dtype=float32),
#  18722: array([ 0.01339234, -0.0072983 ,  0.00241906, -0.02132215], dtype=float32),
#  18832: array([ 0.02617038, -0.00815919,  0.03644756, -0.02600824], dtype=float32),
#  18837: array([ 0.00640338, -0.03417496,  0.02288287, -0.00913207], dtype=float32),
#  18839: array([ 0.01891931, -0.02603205,  0.01933558, -0.02592018], dtype=float32),
#  18856: array([ 0.00977719,  0.0015957 , -0.00057477, -0.01985878], dtype=float32),
#  18889: array([-0.00725267, -0.00374533, -0.01899837, -0.00319987], dtype=float32),
#  18905: array([ 0.02678486, -0.0428831 ,  0.01422058, -0.01823815], dtype=float32),
#  18933: array([ 0.02545824, -0.04590528,  0.03104401, -0.02276161], dtype=float32),
#  18956: array([ 0.03019215, -0.03832953,  0.03554142, -0.02197002], dtype=float32),
#  19007: array([ 0.02781122, -0.02695087,  0.03251547, -0.0193358 ], dtype=float32),
#  19082: array([ 0.01847991, -0.04602529,  0.01455048, -0.01146544], dtype=float32),
#  19120: array([ 0.03843223, -0.02837455,  0.02007121, -0.02037869], dtype=float32),
#  19142: array([ 0.01275574,  0.01074228,  0.01420764, -0.01910727], dtype=float32),
#  19176: array([ 0.01031089, -0.00560963,  0.01044435, -0.01337058], dtype=float32),
#  19180: array([-0.00692731,  0.01400788, -0.0018672 , -0.00587744], dtype=float32),
#  19185: array([ 0.01429499, -0.05123768,  0.00465319, -0.00063681], dtype=float32),
#  19248: array([ 0.01136487,  0.00461171,  0.01502116, -0.02386045], dtype=float32),
#  19249: array([ 0.01553512,  0.00846967,  0.02316723, -0.02018669], dtype=float32),
#  19286: array([ 0.01236025, -0.01631162,  0.00575474, -0.01699103], dtype=float32),
#  19477: array([ 0.02635081, -0.03621013,  0.01287122, -0.01997578], dtype=float32),
#  19563: array([ 0.022723  , -0.03282617,  0.02232552, -0.02052912], dtype=float32),
#  19573: array([ 0.0293279 , -0.03702208,  0.02528099, -0.01704404], dtype=float32),
#  19602: array([ 0.02716953, -0.02388084,  0.03100963, -0.02389369], dtype=float32),
#  19616: array([ 0.02334259, -0.01749752,  0.01647141, -0.02509839], dtype=float32),
#  19632: array([ 0.01883926, -0.03418203,  0.02540719, -0.02714887], dtype=float32),
#  19645: array([ 0.03700887, -0.03923023,  0.03421961, -0.01921387], dtype=float32),
#  19762: array([ 0.02075045, -0.00896974,  0.00760141, -0.00963322], dtype=float32),
#  19842: array([ 0.02586635, -0.02587156,  0.01740429, -0.01870259], dtype=float32),
#  19869: array([ 0.02360836,  0.00315303,  0.01759604, -0.01909246], dtype=float32),
#  19878: array([ 0.02715176, -0.01233735,  0.01428235, -0.02746871], dtype=float32),
#  19880: array([ 0.0251652 , -0.05637119,  0.01811672, -0.01950886], dtype=float32),
#  19882: array([ 0.03938878, -0.03133747,  0.02537452, -0.01672945], dtype=float32),
#  19942: array([ 0.01633535, -0.02877498,  0.02637547, -0.02501096], dtype=float32),
#  19943: array([ 0.02833055, -0.02315863,  0.02991214, -0.02488779], dtype=float32),
#  19951: array([ 0.0051864 , -0.01348068, -0.00611441, -0.00382119], dtype=float32),
#  19988: array([ 0.03064913, -0.05275559,  0.02287472, -0.01925909], dtype=float32),
#  20038: array([ 0.01981251, -0.03659486,  0.01943327, -0.02402316], dtype=float32),
#  20074: array([ 0.0207653 , -0.01773111,  0.00875932, -0.01068337], dtype=float32),
#  20092: array([ 0.03561455, -0.01915132,  0.02278781, -0.01680792], dtype=float32),
#  20104: array([ 0.0309802 , -0.02876174,  0.03291199, -0.02269207], dtype=float32),
#  20105: array([ 0.0371475 , -0.01930394,  0.01361118, -0.0056202 ], dtype=float32),
#  20152: array([ 0.03943406, -0.03641244,  0.01611906, -0.01820034], dtype=float32),
#  20167: array([ 0.02214467, -0.02385242,  0.00978771, -0.01595797], dtype=float32),
#  20244: array([ 0.00474928,  0.00058733, -0.0062982 , -0.01341695], dtype=float32),
#  20251: array([ 0.02487046, -0.01663657,  0.01396781, -0.02023416], dtype=float32),
#  20259: array([ 0.01133281, -0.01369673,  0.02946901, -0.02412215], dtype=float32),
#  20263: array([ 0.01262529, -0.0459868 ,  0.02714231, -0.02108619], dtype=float32),
#  20326: array([ 0.01079116, -0.02318688,  0.03726063, -0.03274258], dtype=float32),
#  20353: array([ 0.01691247, -0.01104062, -0.00077507, -0.02026193], dtype=float32),
#  20359: array([ 0.02126046,  0.00058514,  0.02703124, -0.02751515], dtype=float32),
#  20360: array([ 0.02110798, -0.01395868,  0.01398528, -0.01720227], dtype=float32),
#  20376: array([ 0.02759268, -0.03737184,  0.01110521, -0.01346085], dtype=float32),
# ...
#  27956: array([ 0.02683941, -0.04370334,  0.02052147, -0.02265187], dtype=float32),
#  28035: array([ 0.02441259, -0.02327061,  0.03160623, -0.02159323], dtype=float32),
#  28050: array([ 0.03589968, -0.04035208,  0.02260931, -0.01755474], dtype=float32),
#  28072: array([ 0.01701602, -0.03403037,  0.01807524, -0.01496937], dtype=float32),
#  28085: array([ 0.01584524, -0.02140392,  0.03383536, -0.03228005], dtype=float32),
#  28144: array([ 0.00795462, -0.01277602,  0.01249148, -0.02516387], dtype=float32),
#  28164: array([ 0.03003946, -0.05251579,  0.02728667, -0.02221469], dtype=float32),
#  28220: array([ 0.04705345, -0.01867661,  0.01137035, -0.01561062], dtype=float32),
#  28266: array([ 0.02609269, -0.01312904,  0.02117475, -0.01836142], dtype=float32),
#  28314: array([ 0.03089669, -0.05005202,  0.02712335, -0.02151764], dtype=float32),
#  28328: array([ 0.02186344, -0.02731977,  0.03222024, -0.02401043], dtype=float32),
#  28337: array([ 0.0268433 , -0.04786703,  0.02980413, -0.02252928], dtype=float32),
#  28347: array([ 0.02853481, -0.0200773 ,  0.022062  , -0.02240993], dtype=float32),
#  28365: array([ 0.02166354, -0.01539744,  0.02356868, -0.00982308], dtype=float32),
#  28370: array([ 0.02370956, -0.03357141,  0.03347904, -0.02109007], dtype=float32),
#  28381: array([ 0.02212909, -0.03920987,  0.01556185, -0.0134016 ], dtype=float32),
#  28465: array([ 0.01781489, -0.01424004,  0.01489877, -0.01796709], dtype=float32),
#  28474: array([ 0.02693206, -0.03031671,  0.01801883, -0.01802786], dtype=float32),
#  28489: array([ 0.01965553, -0.03963191,  0.01902865, -0.0261212 ], dtype=float32),
#  28545: array([ 0.02726136, -0.0093357 ,  0.03461719, -0.02426485], dtype=float32),
#  28597: array([ 0.02241369, -0.01418492,  0.0138095 , -0.02090215], dtype=float32),
#  28665: array([ 0.00473565, -0.00047989, -0.00676879, -0.01279808], dtype=float32),
#  28728: array([ 0.02254183, -0.02672315,  0.01930171, -0.01111231], dtype=float32),
#  28753: array([ 0.02074534, -0.03202427,  0.03190341, -0.02096513], dtype=float32),
#  28759: array([ 0.0233405 , -0.04719138,  0.03581487, -0.02549363], dtype=float32),
#  28771: array([ 0.0195356 , -0.02291839,  0.00416973, -0.01616049], dtype=float32),
#  28794: array([ 0.03358445, -0.06248706,  0.01841743, -0.01963375], dtype=float32),
#  28827: array([ 0.00730191,  0.00558703,  0.00109479, -0.02803812], dtype=float32),
#  28905: array([ 0.01674508, -0.04227958,  0.02865347, -0.02327838], dtype=float32),
#  28970: array([ 0.02133084, -0.03296044,  0.03301936, -0.02237941], dtype=float32),
#  28988: array([ 0.02970552, -0.0172078 ,  0.01626458, -0.00968591], dtype=float32),
#  29050: array([ 0.03665299, -0.03400199,  0.03910245, -0.01976574], dtype=float32),
#  29054: array([ 0.02541322, -0.00428896,  0.00697132, -0.01960912], dtype=float32),
#  29066: array([ 0.03118336, -0.04624864,  0.01656475, -0.01720163], dtype=float32),
#  29071: array([ 0.02012398, -0.02257738,  0.00532174, -0.01631549], dtype=float32),
#  29112: array([ 0.01841225, -0.00972439, -0.00016086, -0.02094337], dtype=float32),
#  29113: array([ 0.02243436, -0.02336319,  0.00362545, -0.01835247], dtype=float32),
#  29145: array([ 0.02668801, -0.04449176,  0.0202673 , -0.01888139], dtype=float32),
#  29174: array([ 0.02087733, -0.04216702,  0.03837705, -0.02503353], dtype=float32),
#  29175: array([ 0.02851821, -0.02987076,  0.02200552, -0.022465  ], dtype=float32),
#  29209: array([ 0.03001176, -0.03318947,  0.02473982, -0.02331363], dtype=float32),
#  29228: array([ 0.02780811, -0.0432625 ,  0.02320218, -0.01933803], dtype=float32),
#  29245: array([ 0.02754878, -0.04178365,  0.02880431, -0.01474759], dtype=float32),
#  29256: array([ 0.03976452, -0.02018351,  0.02287246, -0.02017042], dtype=float32),
#  29269: array([ 0.03779955, -0.01540263,  0.02939356, -0.02267241], dtype=float32),
#  29284: array([ 0.0221034 , -0.03168503,  0.02363859, -0.02555204], dtype=float32),
#  29298: array([ 0.01134553, -0.00180347,  0.01018564, -0.01534022], dtype=float32),
#  29329: array([ 0.02994378, -0.0186894 ,  0.01740883, -0.02473762], dtype=float32),
#  29357: array([ 0.02966683, -0.01972596,  0.02470585, -0.02160954], dtype=float32),
#  29419: array([ 0.02437212, -0.04291956,  0.02036556, -0.01902364], dtype=float32),
#  29451: array([ 0.02061314,  0.01280949,  0.02752298, -0.02947293], dtype=float32),
#  29486: array([ 0.02101716, -0.03690648,  0.03937203, -0.02406706], dtype=float32),
#  29507: array([ 0.01907121,  0.01145141,  0.0133421 , -0.02900656], dtype=float32),
#  29510: array([ 0.02335396, -0.00599753,  0.0292534 , -0.01923123], dtype=float32),
#  29515: array([ 0.02129824, -0.04053666,  0.02791798, -0.02165784], dtype=float32),
#  29528: array([ 0.01581096,  0.0130323 ,  0.01770579, -0.02795285], dtype=float32),
#  29570: array([ 0.01940462,  0.00798697,  0.01955825, -0.02400994], dtype=float32),
#  29642: array([ 0.01763472, -0.01223896, -0.00112917, -0.0195978 ], dtype=float32),
#  29647: array([ 0.02203346, -0.01585932,  0.02103724, -0.01591216], dtype=float32),
#  29671: array([ 0.01386182, -0.01559703,  0.00815459, -0.01723468], dtype=float32),
#  29674: array([ 0.0294875 , -0.03759094,  0.03007794, -0.0219461 ], dtype=float32),
#  29718: array([ 0.00930219, -0.0076426 ,  0.00264857, -0.00342234], dtype=float32),
#  29771: array([ 0.02229778, -0.05462908,  0.02294958, -0.02279971], dtype=float32),
#  29784: array([ 0.02731404, -0.04824305,  0.03062293, -0.02286481], dtype=float32),
#  29788: array([ 0.01077563, -0.01649046, -0.00566129, -0.00500972], dtype=float32),
#  29806: array([ 0.02661753, -0.05367757,  0.02785442, -0.02326886], dtype=float32),
#  29867: array([ 0.02723591, -0.05124567,  0.02493785, -0.02171905], dtype=float32),
#  29886: array([ 0.02311211, -0.01111416,  0.0107492 , -0.01705494], dtype=float32),
#  29888: array([ 0.03181669, -0.03385571,  0.0271589 , -0.0183953 ], dtype=float32),
#  29902: array([ 0.01009757, -0.00397549,  0.0063227 , -0.00741356], dtype=float32),
#  29962: array([ 0.02711697, -0.0239259 ,  0.03018917, -0.01947282], dtype=float32),
#  29995: array([ 0.00209174, -0.00439131,  0.00690775, -0.01748206], dtype=float32),
#  29998: array([ 0.01401303, -0.0494105 ,  0.00807084, -0.00215722], dtype=float32),
#  30040: array([ 0.03601652, -0.00880016,  0.0315795 , -0.02285859], dtype=float32),
#  30104: array([ 0.03573218, -0.02896127,  0.01504939, -0.00970169], dtype=float32),
#  30129: array([ 0.03549535, -0.03398295,  0.01439072, -0.0145635 ], dtype=float32),
#  30131: array([ 0.02568462, -0.03795807,  0.0375698 , -0.02288243], dtype=float32),
#  30211: array([ 0.02244831, -0.00525417,  0.03189451, -0.02728648], dtype=float32),
#  30216: array([ 0.01182195, -0.01670261, -0.01067289, -0.010028  ], dtype=float32),
#  30259: array([ 0.01965553, -0.03963191,  0.01902865, -0.0261212 ], dtype=float32),
#  30304: array([ 0.01970438, -0.01546795,  0.01076888, -0.01101353], dtype=float32),
#  30306: array([ 0.0315075 , -0.0373036 ,  0.02062235, -0.02385753], dtype=float32),
#  30411: array([ 0.03391673, -0.04865481,  0.03289001, -0.02170505], dtype=float32),
#  30425: array([ 0.02368743, -0.04799026,  0.00882318, -0.01162702], dtype=float32),
#  30462: array([ 0.01485771, -0.00514781, -0.00336984, -0.01773083], dtype=float32),
#  30466: array([ 0.00709877, -0.03526952,  0.02207603, -0.00856821], dtype=float32),
#  30473: array([ 0.01336556, -0.02531574,  0.01052374, -0.00386537], dtype=float32),
#  30475: array([ 0.00043884, -0.00580637,  0.02101783, -0.01684298], dtype=float32),
#  30479: array([ 0.01577911, -0.03939572,  0.03059639, -0.02333415], dtype=float32),
#  30516: array([ 0.02121556, -0.04183557,  0.01927689, -0.01905292], dtype=float32),
#  30595: array([ 0.01088446, -0.04418681,  0.01234092, -0.00331409], dtype=float32),
#  30598: array([ 0.01268163, -0.04484426,  0.01316041, -0.00536456], dtype=float32),
#  30645: array([ 0.00566193, -0.01099797,  0.01341019, -0.02540835], dtype=float32),
#  30662: array([ 0.01408816, -0.02657694, -0.00985838, -0.00785338], dtype=float32),
#  30675: array([ 0.02012208, -0.03722579,  0.03759491, -0.02388146], dtype=float32),
#  30677: array([ 0.03412864, -0.03728271,  0.03195252, -0.01988367], dtype=float32),
#  30683: array([ 0.0179009 , -0.05459877,  0.00413613, -0.00161674], dtype=float32),
#  30704: array([ 0.02167204, -0.02953315,  0.03548054, -0.02774435], dtype=float32),
#  30735: array([ 0.00936139, -0.0417916 ,  0.01389201, -0.00363236], dtype=float32),
#  30750: array([ 0.02064364, -0.03428319,  0.0297488 , -0.02488044], dtype=float32),
#  30768: array([ 0.02206956, -0.00909305,  0.01506966, -0.02331918], dtype=float32),
#  30787: array([ 0.00894575,  0.00813421,  0.01176016, -0.01745051], dtype=float32),
#  30800: array([ 0.01631049, -0.01240112,  0.00973602, -0.02197032], dtype=float32),
#  30843: array([ 0.02123837,  0.00627351,  0.0171929 , -0.02395819], dtype=float32),
#  30857: array([ 0.01881568, -0.04326947,  0.03459126, -0.02469747], dtype=float32),
#  30866: array([ 0.02591123, -0.03211988,  0.03163077, -0.02036243], dtype=float32),
#  30876: array([ 0.0178282 , -0.04500354,  0.02525218, -0.02241158], dtype=float32),
#  30917: array([ 0.02880032, -0.04907646,  0.01115893, -0.01632851], dtype=float32),
#  30983: array([ 0.00823621, -0.00898202,  0.00585206, -0.01062484], dtype=float32),
#  30989: array([ 0.01217911, -0.01096673,  0.007037  , -0.01056552], dtype=float32),
#  31014: array([ 0.02378735, -0.02797499,  0.02409927, -0.02059088], dtype=float32),
#  31027: array([ 0.02066687, -0.05482846,  0.02682575, -0.02332612], dtype=float32),
#  31035: array([ 0.02578605, -0.05010917,  0.03583832, -0.0241228 ], dtype=float32),
#  31106: array([ 0.02388123, -0.04612236,  0.01580676, -0.0125665 ], dtype=float32),
#  31110: array([ 0.02251716, -0.02464051,  0.02963587, -0.02281567], dtype=float32),
#  31112: array([-0.00134236,  0.01631433,  0.00488792, -0.01615473], dtype=float32),
#  31114: array([ 0.02095068, -0.04281766,  0.0305448 , -0.02291815], dtype=float32),
#  31203: array([ 0.03527117, -0.03285447,  0.01481061, -0.01571877], dtype=float32),
#  31229: array([ 0.01165871, -0.04411215,  0.01390958, -0.00451628], dtype=float32),
#  31237: array([ 0.0297745 , -0.02683095,  0.03861869, -0.0204452 ], dtype=float32),
#  31242: array([ 0.01884619,  0.01387063,  0.01634608, -0.02927919], dtype=float32),
#  31289: array([ 0.02976221, -0.04163415,  0.02490013, -0.02071391], dtype=float32),
#  31323: array([ 0.03024684, -0.02265898,  0.0280696 , -0.00608048], dtype=float32),
#  31396: array([ 0.03216381, -0.040927  ,  0.01668052, -0.01646901], dtype=float32),
#  31445: array([ 0.02344319, -0.05432886,  0.03499175, -0.02530033], dtype=float32),
#  31450: array([ 0.01814382, -0.02629006,  0.02195195, -0.01228997], dtype=float32),
#  31455: array([ 0.0152908 , -0.0208706 ,  0.01080658, -0.01317895], dtype=float32),
#  31463: array([ 0.02112415, -0.00431452,  0.03417077, -0.03272149], dtype=float32),
#  31530: array([ 0.01543428,  0.00724731,  0.00326308, -0.02926558], dtype=float32),
#  31564: array([ 0.04183942, -0.02836664,  0.01730415, -0.02151969], dtype=float32),
#  31568: array([ 0.02362312, -0.03808015,  0.02530001, -0.01487614], dtype=float32),
#  31586: array([ 0.01978814, -0.04360813,  0.02849623, -0.02271821], dtype=float32),
#  31589: array([ 0.02684317, -0.03738457,  0.03336371, -0.02118415], dtype=float32),
#  31618: array([ 0.0265962 , -0.04819439,  0.02939469, -0.0257061 ], dtype=float32),
#  31645: array([ 0.02851069, -0.04831284,  0.04261467, -0.02512904], dtype=float32),
#  31651: array([ 0.01425342, -0.01687844,  0.02568896, -0.02104535], dtype=float32),
#  31686: array([ 0.02419261, -0.03096132,  0.03030289, -0.01963897], dtype=float32),
#  31703: array([ 0.03348097, -0.03391328,  0.02673195, -0.01288786], dtype=float32),
#  31730: array([ 0.02234071, -0.017257  ,  0.02316657, -0.01944164], dtype=float32),
#  31736: array([ 0.02471358, -0.03328605,  0.03674062, -0.02164811], dtype=float32),
#  31739: array([ 0.02271817, -0.04153595,  0.04399455, -0.02580258], dtype=float32),
#  31743: array([ 0.02947092, -0.04212498,  0.03391112, -0.02271301], dtype=float32),
#  31756: array([ 0.02370956, -0.03357141,  0.03347904, -0.02109007], dtype=float32),
#  31771: array([ 0.01645843, -0.00912518,  0.0135646 , -0.02231285], dtype=float32),
#  31800: array([ 0.02655568, -0.02752673,  0.01626557, -0.01108963], dtype=float32),
#  31804: array([ 0.0183001 , -0.01422651,  0.03483529, -0.02756816], dtype=float32),
#  31836: array([ 0.02771531, -0.05529012,  0.03065432, -0.02331046], dtype=float32),
#  31863: array([ 0.0083173 , -0.03909383,  0.01573925, -0.00838436], dtype=float32),
#  31866: array([ 0.02344269, -0.04455299,  0.01750155, -0.01976017], dtype=float32),
#  31914: array([ 0.02088335, -0.03503093,  0.02782281, -0.02039021], dtype=float32),
#  31921: array([ 0.02300378, -0.03880971,  0.03980133, -0.0241126 ], dtype=float32),
#  31926: array([ 0.02037347, -0.04002796,  0.03515222, -0.02392398], dtype=float32),
#  31968: array([ 0.0274653 , -0.05202694,  0.03215837, -0.02395371], dtype=float32),
#  31974: array([ 0.03694912, -0.0182014 ,  0.03086625, -0.0127876 ], dtype=float32),
#  31993: array([ 0.02066371, -0.01595802, -0.00086128, -0.01586829], dtype=float32),
#  32104: array([ 0.02823132, -0.03663791,  0.01879626, -0.01706244], dtype=float32),
#  32109: array([ 0.0251351 , -0.02627135,  0.0065635 , -0.0162714 ], dtype=float32),
#  32123: array([ 0.0166886 , -0.03826642,  0.02579677, -0.02187999], dtype=float32),
#  32132: array([ 0.02187677, -0.01860081,  0.00589819, -0.02123393], dtype=float32),
#  32161: array([ 0.01920329, -0.01800767,  0.00164907, -0.01331703], dtype=float32),
#  32170: array([ 0.01664719, -0.00081171,  0.00461847, -0.02468422], dtype=float32),
#  32222: array([ 0.03221799, -0.04516046,  0.01108737, -0.01537392], dtype=float32),
#  32228: array([ 0.01343125, -0.02326238, -0.00662272, -0.00843615], dtype=float32),
#  32252: array([ 0.01060178, -0.03742211,  0.02229559, -0.01689355], dtype=float32),
#  32293: array([ 0.01685731, -0.03429466,  0.02192622, -0.02333373], dtype=float32),
#  32311: array([ 0.01027886, -0.0350272 , -0.00595926, -0.0045394 ], dtype=float32),
#  32368: array([ 0.01275528, -0.02033227, -0.01365786, -0.0069465 ], dtype=float32),
#  32400: array([ 0.0185359 , -0.00597572,  0.00110423, -0.02293951], dtype=float32),
#  32417: array([ 0.03472836, -0.02832059,  0.02859475, -0.02144448], dtype=float32),
#  32481: array([ 0.01927502, -0.01265211,  0.02380643, -0.02523644], dtype=float32),
#  32499: array([ 0.02102631, -0.05287582,  0.03514215, -0.02553209], dtype=float32),
#  32586: array([ 0.02737472, -0.05185584,  0.0255918 , -0.02209613], dtype=float32),
#  32607: array([ 0.02273216, -0.04579791,  0.01687236, -0.02263736], dtype=float32),
#  32634: array([ 0.02994513, -0.03031657,  0.01872717, -0.0219797 ], dtype=float32),
#  32678: array([ 0.01523881, -0.05075546,  0.00750932, -0.0023212 ], dtype=float32),
#  32748: array([ 0.02320611, -0.03876622,  0.04057728, -0.02423899], dtype=float32),
#  32759: array([ 0.01690047, -0.01778156,  0.00509722, -0.02016506], dtype=float32),
#  32785: array([ 0.01443303, -0.04674129,  0.02100637, -0.01602295], dtype=float32),
#  32821: array([ 0.03105665, -0.04062125,  0.01983111, -0.02207233], dtype=float32),
#  32842: array([ 0.0116399 , -0.0126991 , -0.00126441, -0.00283563], dtype=float32),
#  32856: array([ 0.0196912 , -0.00489309,  0.0186743 , -0.02361099], dtype=float32),
#  32883: array([ 0.0293333 , -0.0235274 ,  0.03136039, -0.02041212], dtype=float32),
#  32900: array([ 0.01499802, -0.02360179,  0.01358331, -0.00552225], dtype=float32),
#  32923: array([ 0.02866151, -0.04119028,  0.01639453, -0.01835706], dtype=float32),
#  32943: array([ 0.02955139, -0.0448752 ,  0.02288794, -0.01924696], dtype=float32),
#  32950: array([ 0.01908665, -0.02211776,  0.02547315, -0.02627629], dtype=float32),
#  32961: array([ 0.01549173, -0.04663857,  0.02659401, -0.02506362], dtype=float32),
#  32978: array([ 0.016482  ,  0.01187202,  0.01767448, -0.02738139], dtype=float32),
#  33047: array([ 0.02974233, -0.02399578,  0.01863652, -0.02123993], dtype=float32),
#  33056: array([ 0.02298888, -0.04828353,  0.01263203, -0.0177624 ], dtype=float32),
#  ...}

# %%
merged_weights = []
new_weights2[0]=[0,0,0,0]
for i in range(len(old_weights)):
#     merged_weights.append(new_weights.get(i, old_weights[i]))
    merged_weights.append(new_weights.get(i, new_weights2.get(i, [0,0,0,0])))

# %%
np.stack(merged_weights)
# Out:
# array([[ 0.03218617, -0.0124478 ,  0.03289796, -0.02452377],
#        [ 0.02852062, -0.02847903,  0.01751459, -0.02489805],
#        [ 0.01670155, -0.03292799,  0.02088702, -0.02560736],
#        ...,
#        [ 0.01984161, -0.00476882,  0.02178208, -0.02275458],
#        [ 0.03083937, -0.01920227,  0.02409153, -0.01022267],
#        [ 0.        ,  0.        ,  0.        ,  0.        ]])

# %%
model.layers[2].set_weights([np.stack(merged_weights)])

# %%
# -np.sum(trainY*train_predict[:,0])/np.sum(np.abs(trainY))

# %%
# -np.sum(trainY*train_predict[:,0] )/np.sum(np.abs(trainY))

# %%
-np.sum(valY*val_predict[:,0] )/np.sum(np.abs(valY))
# -0.22921870322866542
# -0.29499408463224436
# -0.3365937438413243
# -0.34325145608255186
# -0.35394938525789055


# -0.34627157632374744
# Out:
# -0.43540499300279123

# %%
val['predict'] = val_predict[:,0]
# Out:
# /home/ivan/PycharmProjects/tks_stories/venv/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
val.loc[~val.customer_id.isin(set(train.customer_id.values)),'predict'] =-1
# Out:
# /home/ivan/PycharmProjects/tks_stories/venv/lib/python3.6/site-packages/pandas/core/indexing.py:494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s

# %%
-np.sum(valY*val['predict'])/np.sum(np.abs(valY))
# -0.26261507362945524
# -0.29364859095899104
# -0.3315410025698421
# Out:
# -0.4355258749860764
